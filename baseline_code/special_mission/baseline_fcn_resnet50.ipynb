# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#하이퍼파라미터-세팅-및-seed-고정" data-toc-modified-id="하이퍼파라미터-세팅-및-seed-고정-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>하이퍼파라미터 세팅 및 seed 고정</a></span></li><li><span><a href="#학습-데이터-EDA" data-toc-modified-id="학습-데이터-EDA-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>학습 데이터 EDA</a></span></li><li><span><a href="#데이터-전처리-함수-정의-(Dataset)" data-toc-modified-id="데이터-전처리-함수-정의-(Dataset)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>데이터 전처리 함수 정의 (Dataset)</a></span></li><li><span><a href="#Dataset-정의-및-DataLoader-할당" data-toc-modified-id="Dataset-정의-및-DataLoader-할당-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Dataset 정의 및 DataLoader 할당</a></span><ul class="toc-item"><li><span><a href="#데이터-샘플-시각화-(Show-example-image-and-mask)" data-toc-modified-id="데이터-샘플-시각화-(Show-example-image-and-mask)-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>데이터 샘플 시각화 (Show example image and mask)</a></span></li></ul></li><li><span><a href="#baseline-model" data-toc-modified-id="baseline-model-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>baseline model</a></span><ul class="toc-item"><li><span><a href="#models.segmentation.fcn_resnet50" data-toc-modified-id="models.segmentation.fcn_resnet50-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>models.segmentation.fcn_resnet50</a></span></li></ul></li><li><span><a href="#train,-validation,-test-함수-정의" data-toc-modified-id="train,-validation,-test-함수-정의-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>train, validation, test 함수 정의</a></span></li><li><span><a href="#모델-저장-함수-정의" data-toc-modified-id="모델-저장-함수-정의-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>모델 저장 함수 정의</a></span></li><li><span><a href="#모델-생성-및-Loss-function,-Optimizer-정의" data-toc-modified-id="모델-생성-및-Loss-function,-Optimizer-정의-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>모델 생성 및 Loss function, Optimizer 정의</a></span></li><li><span><a href="#저장된-model-불러오기-(학습된-이후)" data-toc-modified-id="저장된-model-불러오기-(학습된-이후)-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>저장된 model 불러오기 (학습된 이후)</a></span><ul class="toc-item"><li><span><a href="#plot_examples()-시각화-함수-정의" data-toc-modified-id="plot_examples()-시각화-함수-정의-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span><code>plot_examples()</code> 시각화 함수 정의</a></span><ul class="toc-item"><li><span><a href="#train-set-시각화" data-toc-modified-id="train-set-시각화-9.1.1"><span class="toc-item-num">9.1.1&nbsp;&nbsp;</span>train set 시각화</a></span></li><li><span><a href="#validation-set-시각화" data-toc-modified-id="validation-set-시각화-9.1.2"><span class="toc-item-num">9.1.2&nbsp;&nbsp;</span>validation set 시각화</a></span></li><li><span><a href="#test-set-시각화" data-toc-modified-id="test-set-시각화-9.1.3"><span class="toc-item-num">9.1.3&nbsp;&nbsp;</span>test set 시각화</a></span></li></ul></li></ul></li><li><span><a href="#submission을-위한-test-함수-정의" data-toc-modified-id="submission을-위한-test-함수-정의-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>submission을 위한 test 함수 정의</a></span></li><li><span><a href="#submission.csv-생성" data-toc-modified-id="submission.csv-생성-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>submission.csv 생성</a></span></li></ul></div>

# %%
import os
import random
import time
import json
import warnings 
warnings.filterwarnings('ignore')

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from utils import label_accuracy_score, add_hist
import cv2

import numpy as np
import pandas as pd
from tqdm import tqdm

# 전처리를 위한 라이브러리
from pycocotools.coco import COCO
import torchvision
import torchvision.transforms as transforms

import albumentations as A
from albumentations.pytorch import ToTensorV2

# 시각화를 위한 라이브러리
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from matplotlib.patches import Patch
import webcolors

plt.rcParams['axes.grid'] = False

print('pytorch version: {}'.format(torch.__version__))
print('GPU 사용 가능 여부: {}'.format(torch.cuda.is_available()))

print(torch.cuda.get_device_name(0))
print(torch.cuda.device_count())

# GPU 사용 가능 여부에 따라 device 정보 저장
device = "cuda" if torch.cuda.is_available() else "cpu"
# Out:
# pytorch version: 1.7.1
# GPU 사용 가능 여부: True
# Tesla V100-SXM2-32GB
# 1

# %% [markdown]
# ## 하이퍼파라미터 세팅 및 seed 고정

# %%
batch_size = 16   # Mini-batch size
num_epochs = 120
learning_rate = 0.0001

# %%
# seed 고정
random_seed = 21
torch.manual_seed(random_seed)
torch.cuda.manual_seed(random_seed)
torch.cuda.manual_seed_all(random_seed) # if use multi-GPU
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(random_seed)
random.seed(random_seed)

# %% [markdown]
# ## 학습 데이터 EDA

# %%
# %matplotlib inline

dataset_path  = '../input/data'
anns_file_path = dataset_path + '/' + 'train_all.json'

# Read annotations
with open(anns_file_path, 'r') as f:
    dataset = json.loads(f.read())

categories = dataset['categories']
anns = dataset['annotations']
imgs = dataset['images']
nr_cats = len(categories)
nr_annotations = len(anns)
nr_images = len(imgs)

# Load categories and super categories
cat_names = []
super_cat_names = []
super_cat_ids = {}
super_cat_last_name = ''
nr_super_cats = 0
for cat_it in categories:
    cat_names.append(cat_it['name'])
    super_cat_name = cat_it['supercategory']
    # Adding new supercat
    if super_cat_name != super_cat_last_name:
        super_cat_names.append(super_cat_name)
        super_cat_ids[super_cat_name] = nr_super_cats
        super_cat_last_name = super_cat_name
        nr_super_cats += 1

print('Number of super categories:', nr_super_cats)
print('Number of categories:', nr_cats)
print('Number of annotations:', nr_annotations)
print('Number of images:', nr_images)
# Out:
# Number of super categories: 10
# Number of categories: 10
# Number of annotations: 26240
# Number of images: 3272

# %%
# Count annotations
cat_histogram = np.zeros(nr_cats,dtype=int)
for ann in anns:
    cat_histogram[ann['category_id']-1] += 1

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(5,5))

# Convert to DataFrame
df = pd.DataFrame({'Categories': cat_names, 'Number of annotations': cat_histogram})
df = df.sort_values('Number of annotations', 0, False)

# Plot the histogram
plt.title("category distribution of train_all set ")
plot_1 = sns.barplot(x="Number of annotations", y="Categories", data=df, label="Total", color="b")

# %%
# category labeling 
sorted_temp_df = df.sort_index()

# background = 0 에 해당되는 label 추가 후 기존들을 모두 label + 1 로 설정
sorted_df = pd.DataFrame(["Backgroud"], columns = ["Categories"])
sorted_df = sorted_df.append(sorted_temp_df, ignore_index=True)

# %%
# class (Categories) 에 따른 index 확인 (0~10 : 총 11개)
sorted_df
# Out:
#        Categories  Number of annotations
# 0       Backgroud                    NaN
# 1   General trash                 2782.0
# 2           Paper                 9311.0
# 3      Paper pack                  659.0
# 4           Metal                  562.0
# 5           Glass                  610.0
# 6         Plastic                 3090.0
# 7       Styrofoam                 1343.0
# 8     Plastic bag                 7643.0
# 9         Battery                   63.0
# 10       Clothing                  177.0

# %% [markdown]
# ## 데이터 전처리 함수 정의 (Dataset)

# %%
category_names = list(sorted_df.Categories)

def get_classname(classID, cats):
    for i in range(len(cats)):
        if cats[i]['id']==classID:
            return cats[i]['name']
    return "None"

class CustomDataLoader(Dataset):
    """COCO format"""
    def __init__(self, data_dir, mode = 'train', transform = None):
        super().__init__()
        self.mode = mode
        self.transform = transform
        self.coco = COCO(data_dir)
        
    def __getitem__(self, index: int):
        # dataset이 index되어 list처럼 동작
        image_id = self.coco.getImgIds(imgIds=index)
        image_infos = self.coco.loadImgs(image_id)[0]
        
        # cv2 를 활용하여 image 불러오기
        images = cv2.imread(os.path.join(dataset_path, image_infos['file_name']))
        images = cv2.cvtColor(images, cv2.COLOR_BGR2RGB).astype(np.float32)
        images /= 255.0
        
        if (self.mode in ('train', 'val')):
            ann_ids = self.coco.getAnnIds(imgIds=image_infos['id'])
            anns = self.coco.loadAnns(ann_ids)

            # Load the categories in a variable
            cat_ids = self.coco.getCatIds()
            cats = self.coco.loadCats(cat_ids)

            # masks : size가 (height x width)인 2D
            # 각각의 pixel 값에는 "category id" 할당
            # Background = 0
            masks = np.zeros((image_infos["height"], image_infos["width"]))
            # General trash = 1, ... , Cigarette = 10
            anns = sorted(anns, key=lambda idx : len(idx['segmentation'][0]), reverse=False)
            for i in range(len(anns)):
                className = get_classname(anns[i]['category_id'], cats)
                pixel_value = category_names.index(className)
                masks[self.coco.annToMask(anns[i]) == 1] = pixel_value
            masks = masks.astype(np.int8)
                        
            # transform -> albumentations 라이브러리 활용
            if self.transform is not None:
                transformed = self.transform(image=images, mask=masks)
                images = transformed["image"]
                masks = transformed["mask"]
            return images, masks, image_infos
        
        if self.mode == 'test':
            # transform -> albumentations 라이브러리 활용
            if self.transform is not None:
                transformed = self.transform(image=images)
                images = transformed["image"]
            return images, image_infos
    
    def __len__(self) -> int:
        # 전체 dataset의 size를 return
        return len(self.coco.getImgIds())

# %% [markdown]
# ## Dataset 정의 및 DataLoader 할당

# %%
# train.json / validation.json / test.json 디렉토리 설정
train_path = dataset_path + '/train.json'
val_path = dataset_path + '/val.json'
test_path = dataset_path + '/test.json'

# collate_fn needs for batch
def collate_fn(batch):
    return tuple(zip(*batch))


import albumentations as A
from albumentations.pytorch import ToTensorV2

train_transform = A.Compose([
                            ToTensorV2()
                            ])

val_transform = A.Compose([
                          ToTensorV2()
                          ])

test_transform = A.Compose([
                           ToTensorV2()
                           ])

# create own Dataset 1 (skip)
# validation set을 직접 나누고 싶은 경우
# random_split 사용하여 data set을 8:2 로 분할
# train_size = int(0.8*len(dataset))
# val_size = int(len(dataset)-train_size)
# dataset = CustomDataLoader(data_dir=train_path, mode='train', transform=transform)
# train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

# create own Dataset 2
# train dataset
train_dataset = CustomDataLoader(data_dir=train_path, mode='train', transform=train_transform)

# validation dataset
val_dataset = CustomDataLoader(data_dir=val_path, mode='val', transform=val_transform)

# test dataset
test_dataset = CustomDataLoader(data_dir=test_path, mode='test', transform=test_transform)


# DataLoader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size,
                                           shuffle=True,
                                           num_workers=4,
                                           collate_fn=collate_fn)

val_loader = torch.utils.data.DataLoader(dataset=val_dataset, 
                                         batch_size=batch_size,
                                         shuffle=False,
                                         num_workers=4,
                                         collate_fn=collate_fn)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          num_workers=4,
                                          collate_fn=collate_fn)
# Out:
# loading annotations into memory...
# Done (t=3.94s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.88s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!

# %% [markdown]
# ### 데이터 샘플 시각화 (Show example image and mask)
#
# - `train_loader`
# - `val_loader`
# - `test_loader`

# %%
class_colormap = pd.read_csv("class_dict.csv")
class_colormap
# Out:
#              name    r    g    b
# 0       Backgroud    0    0    0
# 1   General trash  192    0  128
# 2           Paper    0  128  192
# 3      Paper pack    0  128   64
# 4           Metal  128    0    0
# 5           Glass   64    0  128
# 6         Plastic   64    0  192
# 7       Styrofoam  192  128   64
# 8     Plastic bag  192  192  128
# 9         Battery   64   64  128
# 10       Clothing  128    0  192

# %%
def create_trash_label_colormap():
    """Creates a label colormap used in Trash segmentation.
    Returns:
        A colormap for visualizing segmentation results.
    """
    colormap = np.zeros((11, 3), dtype=np.uint8)
    for inex, (_, r, g, b) in enumerate(class_colormap.values):
        colormap[inex] = [r, g, b]
    
    return colormap

def label_to_color_image(label):
    """Adds color defined by the dataset colormap to the label.

    Args:
        label: A 2D array with integer type, storing the segmentation label.

    Returns:
        result: A 2D array with floating type. The element of the array
                is the color indexed by the corresponding element in the input label
                to the trash color map.

    Raises:
        ValueError: If label is not of rank 2 or its value is larger than color
              map maximum entry.
    """
    if label.ndim != 2:
        raise ValueError('Expect 2-D input label')

    colormap = create_trash_label_colormap()

    if np.max(label) >= len(colormap):
        raise ValueError('label value too large.')

    return colormap[label]

# %%
# train_loader의 output 결과(image 및 mask) 확인
for imgs, masks, image_infos in train_loader:
    image_infos = image_infos[0]
    temp_images = imgs
    temp_masks = masks
    break

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 12))

print('image shape:', list(temp_images[0].shape))
print('mask shape: ', list(temp_masks[0].shape))
print('Unique values, category of transformed mask : \n', [{int(i),category_names[int(i)]} for i in list(np.unique(temp_masks[0]))])

ax1.imshow(temp_images[0].permute([1,2,0]))
ax1.grid(False)
ax1.set_title("input image : {}".format(image_infos['file_name']), fontsize = 15)

ax2.imshow(temp_masks[0])
ax2.grid(False)
ax2.set_title("masks : {}".format(image_infos['file_name']), fontsize = 15)

plt.show()
# Out:
# image shape: [3, 512, 512]
# mask shape:  [512, 512]
# Unique values, category of transformed mask :
#  [{0, 'Backgroud'}, {2, 'Paper'}, {8, 'Plastic bag'}]

# %%
# val_loader의 output 결과(image 및 mask) 확인
for imgs, masks, image_infos in val_loader:
    image_infos = image_infos[0]
    temp_images = imgs
    temp_masks = masks
    
    break

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 12))

print('image shape:', list(temp_images[0].shape))
print('mask shape: ', list(temp_masks[0].shape))

print('Unique values, category of transformed mask : \n', [{int(i),category_names[int(i)]} for i in list(np.unique(temp_masks[0]))])

ax1.imshow(temp_images[0].permute([1,2,0]))
ax1.grid(False)
ax1.set_title("input image : {}".format(image_infos['file_name']), fontsize = 15)

ax2.imshow(temp_masks[0])
ax2.grid(False)
ax2.set_title("masks : {}".format(image_infos['file_name']), fontsize = 15)

plt.show()
# Out:
# image shape: [3, 512, 512]
# mask shape:  [512, 512]
# Unique values, category of transformed mask :
#  [{0, 'Backgroud'}, {'Glass', 5}, {'Plastic', 6}, {8, 'Plastic bag'}]

# %%
# test_loader의 output 결과(image) 확인
for imgs, image_infos in test_loader:
    image_infos = image_infos[0]
    temp_images = imgs
    
    break

fig, ax1 = plt.subplots(nrows=1, ncols=1, figsize=(6, 6))

print('image shape:', list(temp_images[0].shape))

ax1.imshow(temp_images[0].permute([1,2,0]))
ax1.grid(False)
ax1.set_title("input image : {}".format(image_infos['file_name']), fontsize = 15)

plt.show()
# Out:
# image shape: [3, 512, 512]

# %% [markdown]
# ## baseline model
#
# ### models.segmentation.fcn_resnet50

# %%
import torch.nn as nn
import torch.optim as optim
from torchvision import models

model = models.segmentation.fcn_resnet50(pretrained=True)

# output class를 data set에 맞도록 수정
model.classifier[4] = nn.Conv2d(512, 11, kernel_size=1)

# %%
# 구현된 model에 임의의 input을 넣어 output이 잘 나오는지 test
x = torch.randn([2, 3, 512, 512])
print(f"input shape : {x.shape}")
out = model(x)['out']
print(f"output shape : {out.size()}")
# Out:
# input shape : torch.Size([2, 3, 512, 512])
# output shape : torch.Size([2, 11, 512, 512])

# %% [markdown]
# ## train, validation, test 함수 정의

# %%
def train(num_epochs, model, data_loader, val_loader, criterion, optimizer, saved_dir, val_every, device):
    print(f'Start training..')
    n_class = 11
    best_loss = 9999999
    
    for epoch in range(num_epochs):
        model.train()

        hist = np.zeros((n_class, n_class))
        for step, (images, masks, _) in enumerate(data_loader):
            images = torch.stack(images)       
            masks = torch.stack(masks).long() 
            
            # gpu 연산을 위해 device 할당
            images, masks = images.to(device), masks.to(device)
            
            # device 할당
            model = model.to(device)
            
            # inference
            outputs = model(images)['out']
            
            # loss 계산 (cross entropy loss)
            loss = criterion(outputs, masks)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            outputs = torch.argmax(outputs, dim=1).detach().cpu().numpy()
            masks = masks.detach().cpu().numpy()
            
            hist = add_hist(hist, masks, outputs, n_class=n_class)
            acc, acc_cls, mIoU, fwavacc, IoU = label_accuracy_score(hist)
            
            # step 주기에 따른 loss 출력
            if (step + 1) % 25 == 0:
                print(f'Epoch [{epoch+1}/{num_epochs}], Step [{step+1}/{len(train_loader)}], \
                        Loss: {round(loss.item(),4)}, mIoU: {round(mIoU,4)}')
             
        # validation 주기에 따른 loss 출력 및 best model 저장
        if (epoch + 1) % val_every == 0:
            avrg_loss = validation(epoch + 1, model, val_loader, criterion, device)
            if avrg_loss < best_loss:
                print(f"Best performance at epoch: {epoch + 1}")
                print(f"Save model in {saved_dir}")
                best_loss = avrg_loss
                save_model(model, saved_dir)

# %%
def validation(epoch, model, data_loader, criterion, device):
    print(f'Start validation #{epoch}')
    model.eval()

    with torch.no_grad():
        n_class = 11
        total_loss = 0
        cnt = 0
        
        hist = np.zeros((n_class, n_class))
        for step, (images, masks, _) in enumerate(data_loader):
            
            images = torch.stack(images)       
            masks = torch.stack(masks).long()  

            images, masks = images.to(device), masks.to(device)            
            
            # device 할당
            model = model.to(device)
            
            outputs = model(images)['out']
            loss = criterion(outputs, masks)
            total_loss += loss
            cnt += 1
            
            outputs = torch.argmax(outputs, dim=1).detach().cpu().numpy()
            masks = masks.detach().cpu().numpy()
            
            hist = add_hist(hist, masks, outputs, n_class=n_class)
        
        acc, acc_cls, mIoU, fwavacc, IoU = label_accuracy_score(hist)
        IoU_by_class = [{classes : round(IoU,4)} for IoU, classes in zip(IoU , sorted_df['Categories'])]
        
        avrg_loss = total_loss / cnt
        print(f'Validation #{epoch}  Average Loss: {round(avrg_loss.item(), 4)}, Accuracy : {round(acc, 4)}, \
                mIoU: {round(mIoU, 4)}')
        print(f'IoU by class : {IoU_by_class}')
        
    return avrg_loss

# %% [markdown]
# ## 모델 저장 함수 정의

# %%
# 모델 저장 함수 정의
val_every = 1

saved_dir = './saved'
if not os.path.isdir(saved_dir):                                                           
    os.mkdir(saved_dir)

def save_model(model, saved_dir, file_name='fcn_resnet50_best_model(pretrained).pt'):
    check_point = {'net': model.state_dict()}
    output_path = os.path.join(saved_dir, file_name)
    torch.save(model, output_path)

# %% [markdown]
# ## 모델 생성 및 Loss function, Optimizer 정의

# %%
# Loss function 정의
criterion = nn.CrossEntropyLoss()

# Optimizer 정의
optimizer = torch.optim.Adam(params = model.parameters(), lr = learning_rate, weight_decay=1e-6)

# %%
train(num_epochs, model, train_loader, val_loader, criterion, optimizer, saved_dir, val_every, device)
# Out:
# Start training..
# Epoch [1/120], Step [25/164],                         Loss: 1.0847, mIoU: 0.171
# Epoch [1/120], Step [50/164],                         Loss: 0.8262, mIoU: 0.2003
# Epoch [1/120], Step [75/164],                         Loss: 0.7788, mIoU: 0.2149
# Epoch [1/120], Step [100/164],                         Loss: 0.4891, mIoU: 0.2274
# Epoch [1/120], Step [125/164],                         Loss: 0.5265, mIoU: 0.2369
# Epoch [1/120], Step [150/164],                         Loss: 0.6587, mIoU: 0.2498
# Start validation #1
# Validation #1  Average Loss: 0.476, Accuracy : 0.8858,                 mIoU: 0.2904
# IoU by class : [{'Backgroud': 0.9367}, {'General trash': 0.0164}, {'Paper': 0.573}, {'Paper pack': 0.0}, {'Metal': 0.0}, {'Glass': 0.1046}, {'Plastic': 0.279}, {'Styrofoam': 0.5243}, {'Plastic bag': 0.76}, {'Battery': 0.0}, {'Clothing': 0.0}]
# Best performance at epoch: 1
# Save model in ./saved
# Epoch [2/120], Step [25/164],                         Loss: 0.4282, mIoU: 0.358
# Epoch [2/120], Step [50/164],                         Loss: 0.5352, mIoU: 0.3264
# Epoch [2/120], Step [75/164],                         Loss: 0.3059, mIoU: 0.3238
# Epoch [2/120], Step [100/164],                         Loss: 0.4943, mIoU: 0.3257
# Epoch [2/120], Step [125/164],                         Loss: 0.4744, mIoU: 0.3328
# Epoch [2/120], Step [150/164],                         Loss: 0.283, mIoU: 0.3339
# Start validation #2
# Validation #2  Average Loss: 0.3921, Accuracy : 0.8925,                 mIoU: 0.3609
# IoU by class : [{'Backgroud': 0.9358}, {'General trash': 0.2827}, {'Paper': 0.6378}, {'Paper pack': 0.0642}, {'Metal': 0.1893}, {'Glass': 0.213}, {'Plastic': 0.3353}, {'Styrofoam': 0.4728}, {'Plastic bag': 0.7809}, {'Battery': 0.0}, {'Clothing': 0.0584}]
# Best performance at epoch: 2
# Save model in ./saved
# Epoch [3/120], Step [25/164],                         Loss: 0.2482, mIoU: 0.4122
# Epoch [3/120], Step [50/164],                         Loss: 0.3078, mIoU: 0.4155
# Epoch [3/120], Step [75/164],                         Loss: 0.3285, mIoU: 0.4209
# Epoch [3/120], Step [100/164],                         Loss: 0.3375, mIoU: 0.4365
# Epoch [3/120], Step [125/164],                         Loss: 0.2249, mIoU: 0.4423
# Epoch [3/120], Step [150/164],                         Loss: 0.26, mIoU: 0.4385
# Start validation #3
# Validation #3  Average Loss: 0.3663, Accuracy : 0.8943,                 mIoU: 0.4
# IoU by class : [{'Backgroud': 0.9379}, {'General trash': 0.238}, {'Paper': 0.6413}, {'Paper pack': 0.221}, {'Metal': 0.2362}, {'Glass': 0.3522}, {'Plastic': 0.2822}, {'Styrofoam': 0.5027}, {'Plastic bag': 0.7823}, {'Battery': 0.0}, {'Clothing': 0.2064}]
# Best performance at epoch: 3
# Save model in ./saved
# Epoch [4/120], Step [25/164],                         Loss: 0.1766, mIoU: 0.5135
# Epoch [4/120], Step [50/164],                         Loss: 0.1679, mIoU: 0.5288
# Epoch [4/120], Step [75/164],                         Loss: 0.3134, mIoU: 0.5183
# Epoch [4/120], Step [100/164],                         Loss: 0.1576, mIoU: 0.5214
# Epoch [4/120], Step [125/164],                         Loss: 0.2237, mIoU: 0.5209
# Epoch [4/120], Step [150/164],                         Loss: 0.2493, mIoU: 0.5188
# Start validation #4
# Validation #4  Average Loss: 0.3444, Accuracy : 0.8989,                 mIoU: 0.4266
# IoU by class : [{'Backgroud': 0.9396}, {'General trash': 0.2971}, {'Paper': 0.6539}, {'Paper pack': 0.2972}, {'Metal': 0.2512}, {'Glass': 0.3872}, {'Plastic': 0.3409}, {'Styrofoam': 0.5081}, {'Plastic bag': 0.7742}, {'Battery': 0.0}, {'Clothing': 0.2429}]
# Best performance at epoch: 4
# Save model in ./saved
# Epoch [5/120], Step [25/164],                         Loss: 0.145, mIoU: 0.5958
# Epoch [5/120], Step [50/164],                         Loss: 0.1391, mIoU: 0.5982
# Epoch [5/120], Step [75/164],                         Loss: 0.2124, mIoU: 0.5976
# Epoch [5/120], Step [100/164],                         Loss: 0.1081, mIoU: 0.6012
# Epoch [5/120], Step [125/164],                         Loss: 0.2098, mIoU: 0.6009
# Epoch [5/120], Step [150/164],                         Loss: 0.1823, mIoU: 0.5994
# Start validation #5
# Validation #5  Average Loss: 0.3266, Accuracy : 0.9049,                 mIoU: 0.4266
# IoU by class : [{'Backgroud': 0.9431}, {'General trash': 0.294}, {'Paper': 0.6631}, {'Paper pack': 0.3205}, {'Metal': 0.251}, {'Glass': 0.2659}, {'Plastic': 0.3123}, {'Styrofoam': 0.5821}, {'Plastic bag': 0.8134}, {'Battery': 0.0}, {'Clothing': 0.2474}]
# Best performance at epoch: 5
# Save model in ./saved
# Epoch [6/120], Step [25/164],                         Loss: 0.1135, mIoU: 0.6458
# Epoch [6/120], Step [50/164],                         Loss: 0.1328, mIoU: 0.662
# Epoch [6/120], Step [75/164],                         Loss: 0.0876, mIoU: 0.6645
# Epoch [6/120], Step [100/164],                         Loss: 0.2313, mIoU: 0.6634
# Epoch [6/120], Step [125/164],                         Loss: 0.1615, mIoU: 0.6617
# Epoch [6/120], Step [150/164],                         Loss: 0.2095, mIoU: 0.6545
# Start validation #6
# Validation #6  Average Loss: 0.3477, Accuracy : 0.9019,                 mIoU: 0.4292
# IoU by class : [{'Backgroud': 0.9379}, {'General trash': 0.3156}, {'Paper': 0.6985}, {'Paper pack': 0.2373}, {'Metal': 0.2765}, {'Glass': 0.3819}, {'Plastic': 0.2921}, {'Styrofoam': 0.5948}, {'Plastic bag': 0.7925}, {'Battery': 0.0}, {'Clothing': 0.1941}]
# Epoch [7/120], Step [25/164],                         Loss: 0.2895, mIoU: 0.6698
# Epoch [7/120], Step [50/164],                         Loss: 0.105, mIoU: 0.7167
# Epoch [7/120], Step [75/164],                         Loss: 0.13, mIoU: 0.726
# Epoch [7/120], Step [100/164],                         Loss: 0.1378, mIoU: 0.722
# Epoch [7/120], Step [125/164],                         Loss: 0.1413, mIoU: 0.7174
# Epoch [7/120], Step [150/164],                         Loss: 0.1356, mIoU: 0.7195
# Start validation #7
# Validation #7  Average Loss: 0.3251, Accuracy : 0.9109,                 mIoU: 0.4546
# IoU by class : [{'Backgroud': 0.9433}, {'General trash': 0.3326}, {'Paper': 0.6924}, {'Paper pack': 0.3057}, {'Metal': 0.2708}, {'Glass': 0.4141}, {'Plastic': 0.3648}, {'Styrofoam': 0.6134}, {'Plastic bag': 0.7943}, {'Battery': 0.0}, {'Clothing': 0.269}]
# Best performance at epoch: 7
# Save model in ./saved
# Epoch [8/120], Step [25/164],                         Loss: 0.0904, mIoU: 0.7555
# Epoch [8/120], Step [50/164],                         Loss: 0.1116, mIoU: 0.7301
# Epoch [8/120], Step [75/164],                         Loss: 0.0949, mIoU: 0.7412
# Epoch [8/120], Step [100/164],                         Loss: 0.1491, mIoU: 0.7473
# Epoch [8/120], Step [125/164],                         Loss: 0.0761, mIoU: 0.7392
# Epoch [8/120], Step [150/164],                         Loss: 0.0768, mIoU: 0.7451
# Start validation #8
# Validation #8  Average Loss: 0.37, Accuracy : 0.9033,                 mIoU: 0.4325
# IoU by class : [{'Backgroud': 0.9456}, {'General trash': 0.2734}, {'Paper': 0.68}, {'Paper pack': 0.2046}, {'Metal': 0.1499}, {'Glass': 0.4211}, {'Plastic': 0.3435}, {'Styrofoam': 0.5927}, {'Plastic bag': 0.7712}, {'Battery': 0.1121}, {'Clothing': 0.2634}]
# Epoch [9/120], Step [25/164],                         Loss: 0.0962, mIoU: 0.7884
# Epoch [9/120], Step [50/164],                         Loss: 0.0806, mIoU: 0.7979
# Epoch [9/120], Step [75/164],                         Loss: 0.0629, mIoU: 0.8055
# Epoch [9/120], Step [100/164],                         Loss: 0.0993, mIoU: 0.8068
# Epoch [9/120], Step [125/164],                         Loss: 0.1299, mIoU: 0.8037
# Epoch [9/120], Step [150/164],                         Loss: 0.0744, mIoU: 0.8029
# Start validation #9
# Validation #9  Average Loss: 0.3564, Accuracy : 0.9054,                 mIoU: 0.4552
# IoU by class : [{'Backgroud': 0.9456}, {'General trash': 0.2453}, {'Paper': 0.6468}, {'Paper pack': 0.319}, {'Metal': 0.3016}, {'Glass': 0.4154}, {'Plastic': 0.3217}, {'Styrofoam': 0.5607}, {'Plastic bag': 0.8032}, {'Battery': 0.1823}, {'Clothing': 0.2656}]
# Epoch [10/120], Step [25/164],                         Loss: 0.0918, mIoU: 0.84
# Epoch [10/120], Step [50/164],                         Loss: 0.0911, mIoU: 0.8627
# Epoch [10/120], Step [75/164],                         Loss: 0.1039, mIoU: 0.8581
# Epoch [10/120], Step [100/164],                         Loss: 0.0771, mIoU: 0.845
# Epoch [10/120], Step [125/164],                         Loss: 0.0933, mIoU: 0.8396
# Epoch [10/120], Step [150/164],                         Loss: 0.1708, mIoU: 0.8344
# Start validation #10
# Validation #10  Average Loss: 0.3495, Accuracy : 0.9082,                 mIoU: 0.4713
# IoU by class : [{'Backgroud': 0.9437}, {'General trash': 0.34}, {'Paper': 0.6779}, {'Paper pack': 0.1435}, {'Metal': 0.3142}, {'Glass': 0.4277}, {'Plastic': 0.3555}, {'Styrofoam': 0.5999}, {'Plastic bag': 0.7926}, {'Battery': 0.3164}, {'Clothing': 0.2728}]
# Epoch [11/120], Step [25/164],                         Loss: 0.0833, mIoU: 0.8424
# Epoch [11/120], Step [50/164],                         Loss: 0.0691, mIoU: 0.8424
# Epoch [11/120], Step [75/164],                         Loss: 0.1513, mIoU: 0.8538
# Epoch [11/120], Step [100/164],                         Loss: 0.0652, mIoU: 0.862
# Epoch [11/120], Step [125/164],                         Loss: 0.0899, mIoU: 0.8675
# Epoch [11/120], Step [150/164],                         Loss: 0.0633, mIoU: 0.8679
# Start validation #11
# Validation #11  Average Loss: 0.3438, Accuracy : 0.9128,                 mIoU: 0.5078
# IoU by class : [{'Backgroud': 0.9493}, {'General trash': 0.3097}, {'Paper': 0.7078}, {'Paper pack': 0.3173}, {'Metal': 0.335}, {'Glass': 0.4544}, {'Plastic': 0.3567}, {'Styrofoam': 0.652}, {'Plastic bag': 0.7957}, {'Battery': 0.4366}, {'Clothing': 0.2713}]
# Epoch [12/120], Step [25/164],                         Loss: 0.0961, mIoU: 0.8924
# Epoch [12/120], Step [50/164],                         Loss: 0.0566, mIoU: 0.8887
# Epoch [12/120], Step [75/164],                         Loss: 0.0832, mIoU: 0.8745
# Epoch [12/120], Step [100/164],                         Loss: 0.0418, mIoU: 0.8703
# Epoch [12/120], Step [125/164],                         Loss: 0.1089, mIoU: 0.8716
# Epoch [12/120], Step [150/164],                         Loss: 0.0551, mIoU: 0.8671
# Start validation #12
# Validation #12  Average Loss: 0.3689, Accuracy : 0.9082,                 mIoU: 0.4735
# IoU by class : [{'Backgroud': 0.9451}, {'General trash': 0.3067}, {'Paper': 0.6805}, {'Paper pack': 0.2776}, {'Metal': 0.2652}, {'Glass': 0.4005}, {'Plastic': 0.3453}, {'Styrofoam': 0.6218}, {'Plastic bag': 0.8006}, {'Battery': 0.359}, {'Clothing': 0.2063}]
# Epoch [13/120], Step [25/164],                         Loss: 0.051, mIoU: 0.8922
# Epoch [13/120], Step [50/164],                         Loss: 0.0532, mIoU: 0.8952
# Epoch [13/120], Step [75/164],                         Loss: 0.0785, mIoU: 0.8888
# Epoch [13/120], Step [100/164],                         Loss: 0.0604, mIoU: 0.8866
# Epoch [13/120], Step [125/164],                         Loss: 0.0345, mIoU: 0.8839
# Epoch [13/120], Step [150/164],                         Loss: 0.0519, mIoU: 0.8869
# Start validation #13
# Validation #13  Average Loss: 0.3735, Accuracy : 0.913,                 mIoU: 0.5004
# IoU by class : [{'Backgroud': 0.947}, {'General trash': 0.3421}, {'Paper': 0.6864}, {'Paper pack': 0.318}, {'Metal': 0.2916}, {'Glass': 0.4345}, {'Plastic': 0.3089}, {'Styrofoam': 0.6569}, {'Plastic bag': 0.8021}, {'Battery': 0.4083}, {'Clothing': 0.3089}]
# Epoch [14/120], Step [25/164],                         Loss: 0.0441, mIoU: 0.8968
# Epoch [14/120], Step [50/164],                         Loss: 0.0396, mIoU: 0.895
# Epoch [14/120], Step [75/164],                         Loss: 0.0897, mIoU: 0.8974
# Epoch [14/120], Step [100/164],                         Loss: 0.0581, mIoU: 0.8974
# Epoch [14/120], Step [125/164],                         Loss: 0.0671, mIoU: 0.8992
# Epoch [14/120], Step [150/164],                         Loss: 0.0433, mIoU: 0.898
# Start validation #14
# Validation #14  Average Loss: 0.3615, Accuracy : 0.9106,                 mIoU: 0.5011
# IoU by class : [{'Backgroud': 0.943}, {'General trash': 0.3489}, {'Paper': 0.7102}, {'Paper pack': 0.3544}, {'Metal': 0.3232}, {'Glass': 0.3808}, {'Plastic': 0.3514}, {'Styrofoam': 0.6347}, {'Plastic bag': 0.8086}, {'Battery': 0.4303}, {'Clothing': 0.2266}]
# Epoch [15/120], Step [25/164],                         Loss: 0.0382, mIoU: 0.9143
# Epoch [15/120], Step [50/164],                         Loss: 0.0362, mIoU: 0.9233
# Epoch [15/120], Step [75/164],                         Loss: 0.0276, mIoU: 0.9236
# Epoch [15/120], Step [100/164],                         Loss: 0.041, mIoU: 0.9255
# Epoch [15/120], Step [125/164],                         Loss: 0.0452, mIoU: 0.9244
# Epoch [15/120], Step [150/164],                         Loss: 0.0466, mIoU: 0.9247
# Start validation #15
# Validation #15  Average Loss: 0.365, Accuracy : 0.9158,                 mIoU: 0.503
# IoU by class : [{'Backgroud': 0.9493}, {'General trash': 0.3604}, {'Paper': 0.6954}, {'Paper pack': 0.3176}, {'Metal': 0.2906}, {'Glass': 0.2755}, {'Plastic': 0.372}, {'Styrofoam': 0.6492}, {'Plastic bag': 0.814}, {'Battery': 0.5178}, {'Clothing': 0.2912}]
# Epoch [16/120], Step [25/164],                         Loss: 0.055, mIoU: 0.9225
# Epoch [16/120], Step [50/164],                         Loss: 0.0311, mIoU: 0.927
# Epoch [16/120], Step [75/164],                         Loss: 0.0536, mIoU: 0.9288
# Epoch [16/120], Step [100/164],                         Loss: 0.034, mIoU: 0.9339
# Epoch [16/120], Step [125/164],                         Loss: 0.0325, mIoU: 0.9351
# Epoch [16/120], Step [150/164],                         Loss: 0.0468, mIoU: 0.9343
# Start validation #16
# Validation #16  Average Loss: 0.3792, Accuracy : 0.9155,                 mIoU: 0.5095
# IoU by class : [{'Backgroud': 0.9492}, {'General trash': 0.3622}, {'Paper': 0.6926}, {'Paper pack': 0.3379}, {'Metal': 0.2537}, {'Glass': 0.3917}, {'Plastic': 0.3871}, {'Styrofoam': 0.6488}, {'Plastic bag': 0.8151}, {'Battery': 0.4992}, {'Clothing': 0.2672}]
# Epoch [17/120], Step [25/164],                         Loss: 0.0465, mIoU: 0.9178
# Epoch [17/120], Step [50/164],                         Loss: 0.0531, mIoU: 0.9197
# Epoch [17/120], Step [75/164],                         Loss: 0.0439, mIoU: 0.9075
# Epoch [17/120], Step [100/164],                         Loss: 0.0604, mIoU: 0.9058
# Epoch [17/120], Step [125/164],                         Loss: 0.0818, mIoU: 0.8966
# Epoch [17/120], Step [150/164],                         Loss: 0.1411, mIoU: 0.8849
# Start validation #17
# Validation #17  Average Loss: 0.5404, Accuracy : 0.8724,                 mIoU: 0.3719
# IoU by class : [{'Backgroud': 0.9208}, {'General trash': 0.2295}, {'Paper': 0.5629}, {'Paper pack': 0.2252}, {'Metal': 0.2717}, {'Glass': 0.3469}, {'Plastic': 0.2842}, {'Styrofoam': 0.3841}, {'Plastic bag': 0.693}, {'Battery': 0.017}, {'Clothing': 0.1556}]
# Epoch [18/120], Step [25/164],                         Loss: 0.0729, mIoU: 0.6948
# Epoch [18/120], Step [50/164],                         Loss: 0.0883, mIoU: 0.742
# Epoch [18/120], Step [75/164],                         Loss: 0.2365, mIoU: 0.7554
# Epoch [18/120], Step [100/164],                         Loss: 0.0732, mIoU: 0.7724
# Epoch [18/120], Step [125/164],                         Loss: 0.0678, mIoU: 0.7951
# Epoch [18/120], Step [150/164],                         Loss: 0.0814, mIoU: 0.8057
# Start validation #18
# Validation #18  Average Loss: 0.3961, Accuracy : 0.9025,                 mIoU: 0.4611
# IoU by class : [{'Backgroud': 0.9411}, {'General trash': 0.277}, {'Paper': 0.6503}, {'Paper pack': 0.2166}, {'Metal': 0.2606}, {'Glass': 0.4386}, {'Plastic': 0.2857}, {'Styrofoam': 0.5455}, {'Plastic bag': 0.7764}, {'Battery': 0.3599}, {'Clothing': 0.32}]
# Epoch [19/120], Step [25/164],                         Loss: 0.0567, mIoU: 0.8682
# Epoch [19/120], Step [50/164],                         Loss: 0.0464, mIoU: 0.8939
# Epoch [19/120], Step [75/164],                         Loss: 0.0584, mIoU: 0.8991
# Epoch [19/120], Step [100/164],                         Loss: 0.0411, mIoU: 0.9035
# Epoch [19/120], Step [125/164],                         Loss: 0.066, mIoU: 0.9073
# Epoch [19/120], Step [150/164],                         Loss: 0.0405, mIoU: 0.91
# Start validation #19
# Validation #19  Average Loss: 0.3686, Accuracy : 0.9161,                 mIoU: 0.5149
# IoU by class : [{'Backgroud': 0.948}, {'General trash': 0.3569}, {'Paper': 0.7066}, {'Paper pack': 0.3158}, {'Metal': 0.3442}, {'Glass': 0.4243}, {'Plastic': 0.3671}, {'Styrofoam': 0.6103}, {'Plastic bag': 0.8047}, {'Battery': 0.4775}, {'Clothing': 0.3083}]
# Epoch [20/120], Step [25/164],                         Loss: 0.0267, mIoU: 0.9386
# Epoch [20/120], Step [50/164],                         Loss: 0.0349, mIoU: 0.9399
# Epoch [20/120], Step [75/164],                         Loss: 0.0436, mIoU: 0.9406
# Epoch [20/120], Step [100/164],                         Loss: 0.0341, mIoU: 0.9405
# Epoch [20/120], Step [125/164],                         Loss: 0.0306, mIoU: 0.9408
# Epoch [20/120], Step [150/164],                         Loss: 0.0203, mIoU: 0.9406
# Start validation #20
# Validation #20  Average Loss: 0.368, Accuracy : 0.9172,                 mIoU: 0.5208
# IoU by class : [{'Backgroud': 0.9499}, {'General trash': 0.3658}, {'Paper': 0.7134}, {'Paper pack': 0.3293}, {'Metal': 0.3256}, {'Glass': 0.4334}, {'Plastic': 0.3775}, {'Styrofoam': 0.6314}, {'Plastic bag': 0.8159}, {'Battery': 0.4885}, {'Clothing': 0.2983}]
# Epoch [21/120], Step [25/164],                         Loss: 0.0368, mIoU: 0.9527
# Epoch [21/120], Step [50/164],                         Loss: 0.0353, mIoU: 0.9494
# Epoch [21/120], Step [75/164],                         Loss: 0.0499, mIoU: 0.9495
# Epoch [21/120], Step [100/164],                         Loss: 0.0349, mIoU: 0.9494
# Epoch [21/120], Step [125/164],                         Loss: 0.0345, mIoU: 0.9492
# Epoch [21/120], Step [150/164],                         Loss: 0.053, mIoU: 0.9496
# Start validation #21
# Validation #21  Average Loss: 0.3776, Accuracy : 0.9187,                 mIoU: 0.5087
# IoU by class : [{'Backgroud': 0.9507}, {'General trash': 0.3684}, {'Paper': 0.7181}, {'Paper pack': 0.3504}, {'Metal': 0.3289}, {'Glass': 0.4377}, {'Plastic': 0.3687}, {'Styrofoam': 0.6474}, {'Plastic bag': 0.8148}, {'Battery': 0.3041}, {'Clothing': 0.3061}]
# Epoch [22/120], Step [25/164],                         Loss: 0.0273, mIoU: 0.9515
# Epoch [22/120], Step [50/164],                         Loss: 0.021, mIoU: 0.9537
# Epoch [22/120], Step [75/164],                         Loss: 0.018, mIoU: 0.9528
# Epoch [22/120], Step [100/164],                         Loss: 0.035, mIoU: 0.9535
# Epoch [22/120], Step [125/164],                         Loss: 0.03, mIoU: 0.9544
# Epoch [22/120], Step [150/164],                         Loss: 0.032, mIoU: 0.9538
# Start validation #22
# Validation #22  Average Loss: 0.3894, Accuracy : 0.919,                 mIoU: 0.5127
# IoU by class : [{'Backgroud': 0.9493}, {'General trash': 0.367}, {'Paper': 0.7118}, {'Paper pack': 0.3119}, {'Metal': 0.3423}, {'Glass': 0.4611}, {'Plastic': 0.382}, {'Styrofoam': 0.6468}, {'Plastic bag': 0.8144}, {'Battery': 0.3613}, {'Clothing': 0.2923}]
# Epoch [23/120], Step [25/164],                         Loss: 0.0333, mIoU: 0.9513
# Epoch [23/120], Step [50/164],                         Loss: 0.0298, mIoU: 0.9551
# Epoch [23/120], Step [75/164],                         Loss: 0.0282, mIoU: 0.9551
# Epoch [23/120], Step [100/164],                         Loss: 0.0231, mIoU: 0.9551
# Epoch [23/120], Step [125/164],                         Loss: 0.0239, mIoU: 0.9561
# Epoch [23/120], Step [150/164],                         Loss: 0.0382, mIoU: 0.9565
# Start validation #23
# Validation #23  Average Loss: 0.393, Accuracy : 0.9192,                 mIoU: 0.5224
# IoU by class : [{'Backgroud': 0.9516}, {'General trash': 0.3696}, {'Paper': 0.7173}, {'Paper pack': 0.3402}, {'Metal': 0.3273}, {'Glass': 0.4555}, {'Plastic': 0.3638}, {'Styrofoam': 0.6455}, {'Plastic bag': 0.8186}, {'Battery': 0.4632}, {'Clothing': 0.294}]
# Epoch [24/120], Step [25/164],                         Loss: 0.0262, mIoU: 0.9578
# Epoch [24/120], Step [50/164],                         Loss: 0.0195, mIoU: 0.957
# Epoch [24/120], Step [75/164],                         Loss: 0.0268, mIoU: 0.9573
# Epoch [24/120], Step [100/164],                         Loss: 0.0212, mIoU: 0.9585
# Epoch [24/120], Step [125/164],                         Loss: 0.0339, mIoU: 0.9566
# Epoch [24/120], Step [150/164],                         Loss: 0.0409, mIoU: 0.9562
# Start validation #24
# Validation #24  Average Loss: 0.4014, Accuracy : 0.9156,                 mIoU: 0.5091
# IoU by class : [{'Backgroud': 0.9497}, {'General trash': 0.3712}, {'Paper': 0.6947}, {'Paper pack': 0.3184}, {'Metal': 0.319}, {'Glass': 0.4604}, {'Plastic': 0.3552}, {'Styrofoam': 0.6043}, {'Plastic bag': 0.8157}, {'Battery': 0.4329}, {'Clothing': 0.2785}]
# Epoch [25/120], Step [25/164],                         Loss: 0.0283, mIoU: 0.9581
# Epoch [25/120], Step [50/164],                         Loss: 0.0317, mIoU: 0.9599
# Epoch [25/120], Step [75/164],                         Loss: 0.0282, mIoU: 0.9598
# Epoch [25/120], Step [100/164],                         Loss: 0.0302, mIoU: 0.9596
# Epoch [25/120], Step [125/164],                         Loss: 0.0246, mIoU: 0.9585
# Epoch [25/120], Step [150/164],                         Loss: 0.0464, mIoU: 0.958
# Start validation #25
# Validation #25  Average Loss: 0.4186, Accuracy : 0.9175,                 mIoU: 0.515
# IoU by class : [{'Backgroud': 0.9498}, {'General trash': 0.3687}, {'Paper': 0.7143}, {'Paper pack': 0.3208}, {'Metal': 0.3075}, {'Glass': 0.46}, {'Plastic': 0.3688}, {'Styrofoam': 0.6466}, {'Plastic bag': 0.8116}, {'Battery': 0.4078}, {'Clothing': 0.3088}]
# Epoch [26/120], Step [25/164],                         Loss: 0.0285, mIoU: 0.9629
# Epoch [26/120], Step [50/164],                         Loss: 0.0251, mIoU: 0.9611
# Epoch [26/120], Step [75/164],                         Loss: 0.0246, mIoU: 0.961
# Epoch [26/120], Step [100/164],                         Loss: 0.024, mIoU: 0.9617
# Epoch [26/120], Step [125/164],                         Loss: 0.0319, mIoU: 0.962
# Epoch [26/120], Step [150/164],                         Loss: 0.0439, mIoU: 0.9609
# Start validation #26
# Validation #26  Average Loss: 0.4125, Accuracy : 0.9178,                 mIoU: 0.5052
# IoU by class : [{'Backgroud': 0.9505}, {'General trash': 0.3676}, {'Paper': 0.7202}, {'Paper pack': 0.3257}, {'Metal': 0.2761}, {'Glass': 0.4493}, {'Plastic': 0.3623}, {'Styrofoam': 0.648}, {'Plastic bag': 0.8169}, {'Battery': 0.4049}, {'Clothing': 0.2355}]
# Epoch [27/120], Step [25/164],                         Loss: 0.0143, mIoU: 0.9626
# Epoch [27/120], Step [50/164],                         Loss: 0.0235, mIoU: 0.9608
# Epoch [27/120], Step [75/164],                         Loss: 0.025, mIoU: 0.9621
# Epoch [27/120], Step [100/164],                         Loss: 0.0274, mIoU: 0.963
# Epoch [27/120], Step [125/164],                         Loss: 0.0192, mIoU: 0.9634
# Epoch [27/120], Step [150/164],                         Loss: 0.0296, mIoU: 0.9623
# Start validation #27
# Validation #27  Average Loss: 0.4296, Accuracy : 0.9178,                 mIoU: 0.5062
# IoU by class : [{'Backgroud': 0.9495}, {'General trash': 0.3694}, {'Paper': 0.7096}, {'Paper pack': 0.3266}, {'Metal': 0.2658}, {'Glass': 0.4273}, {'Plastic': 0.3797}, {'Styrofoam': 0.6464}, {'Plastic bag': 0.8206}, {'Battery': 0.398}, {'Clothing': 0.275}]
# Epoch [28/120], Step [25/164],                         Loss: 0.0321, mIoU: 0.9588
# Epoch [28/120], Step [50/164],                         Loss: 0.0195, mIoU: 0.9593
# Epoch [28/120], Step [75/164],                         Loss: 0.0188, mIoU: 0.9601
# Epoch [28/120], Step [100/164],                         Loss: 0.0181, mIoU: 0.9617
# Epoch [28/120], Step [125/164],                         Loss: 0.0235, mIoU: 0.9618
# Epoch [28/120], Step [150/164],                         Loss: 0.0239, mIoU: 0.9626
# Start validation #28
# Validation #28  Average Loss: 0.4243, Accuracy : 0.9181,                 mIoU: 0.5155
# IoU by class : [{'Backgroud': 0.951}, {'General trash': 0.3695}, {'Paper': 0.7129}, {'Paper pack': 0.3013}, {'Metal': 0.3049}, {'Glass': 0.4571}, {'Plastic': 0.3664}, {'Styrofoam': 0.639}, {'Plastic bag': 0.8186}, {'Battery': 0.4963}, {'Clothing': 0.2533}]
# Epoch [29/120], Step [25/164],                         Loss: 0.0344, mIoU: 0.9604
# Epoch [29/120], Step [50/164],                         Loss: 0.0294, mIoU: 0.9628
# Epoch [29/120], Step [75/164],                         Loss: 0.0264, mIoU: 0.9644
# Epoch [29/120], Step [100/164],                         Loss: 0.033, mIoU: 0.9651
# Epoch [29/120], Step [125/164],                         Loss: 0.0187, mIoU: 0.9647
# Epoch [29/120], Step [150/164],                         Loss: 0.0161, mIoU: 0.9645
# Start validation #29
# Validation #29  Average Loss: 0.4356, Accuracy : 0.9179,                 mIoU: 0.5107
# IoU by class : [{'Backgroud': 0.9505}, {'General trash': 0.3523}, {'Paper': 0.7163}, {'Paper pack': 0.317}, {'Metal': 0.293}, {'Glass': 0.4136}, {'Plastic': 0.3794}, {'Styrofoam': 0.646}, {'Plastic bag': 0.82}, {'Battery': 0.4513}, {'Clothing': 0.2781}]
# Epoch [30/120], Step [25/164],                         Loss: 0.0143, mIoU: 0.9638
# Epoch [30/120], Step [50/164],                         Loss: 0.0205, mIoU: 0.9663
# Epoch [30/120], Step [75/164],                         Loss: 0.0196, mIoU: 0.9654
# Epoch [30/120], Step [100/164],                         Loss: 0.0238, mIoU: 0.9661
# Epoch [30/120], Step [125/164],                         Loss: 0.0228, mIoU: 0.9659
# Epoch [30/120], Step [150/164],                         Loss: 0.0234, mIoU: 0.9663
# Start validation #30
# Validation #30  Average Loss: 0.4438, Accuracy : 0.9188,                 mIoU: 0.5175
# IoU by class : [{'Backgroud': 0.9517}, {'General trash': 0.366}, {'Paper': 0.7155}, {'Paper pack': 0.3185}, {'Metal': 0.2966}, {'Glass': 0.4443}, {'Plastic': 0.3727}, {'Styrofoam': 0.6421}, {'Plastic bag': 0.8192}, {'Battery': 0.4594}, {'Clothing': 0.3062}]
# Epoch [31/120], Step [25/164],                         Loss: 0.024, mIoU: 0.9655
# Epoch [31/120], Step [50/164],                         Loss: 0.018, mIoU: 0.9676
# Epoch [31/120], Step [75/164],                         Loss: 0.0237, mIoU: 0.9665
# Epoch [31/120], Step [100/164],                         Loss: 0.013, mIoU: 0.9667
# Epoch [31/120], Step [125/164],                         Loss: 0.0182, mIoU: 0.967
# Epoch [31/120], Step [150/164],                         Loss: 0.0221, mIoU: 0.9677
# Start validation #31
# Validation #31  Average Loss: 0.452, Accuracy : 0.919,                 mIoU: 0.5203
# IoU by class : [{'Backgroud': 0.9504}, {'General trash': 0.3629}, {'Paper': 0.719}, {'Paper pack': 0.3031}, {'Metal': 0.3085}, {'Glass': 0.4596}, {'Plastic': 0.3807}, {'Styrofoam': 0.6574}, {'Plastic bag': 0.8173}, {'Battery': 0.4945}, {'Clothing': 0.2703}]
# Epoch [32/120], Step [25/164],                         Loss: 0.0159, mIoU: 0.9744
# Epoch [32/120], Step [50/164],                         Loss: 0.0175, mIoU: 0.9737
# Epoch [32/120], Step [75/164],                         Loss: 0.0195, mIoU: 0.9724
# Epoch [32/120], Step [100/164],                         Loss: 0.021, mIoU: 0.9718
# Epoch [32/120], Step [125/164],                         Loss: 0.0188, mIoU: 0.9712
# Epoch [32/120], Step [150/164],                         Loss: 0.0136, mIoU: 0.9698
# Start validation #32
# Validation #32  Average Loss: 0.4441, Accuracy : 0.9182,                 mIoU: 0.5167
# IoU by class : [{'Backgroud': 0.952}, {'General trash': 0.3547}, {'Paper': 0.7179}, {'Paper pack': 0.3118}, {'Metal': 0.2833}, {'Glass': 0.4718}, {'Plastic': 0.3742}, {'Styrofoam': 0.6467}, {'Plastic bag': 0.8215}, {'Battery': 0.4382}, {'Clothing': 0.3118}]
# Epoch [33/120], Step [25/164],                         Loss: 0.0206, mIoU: 0.9696
# Epoch [33/120], Step [50/164],                         Loss: 0.0263, mIoU: 0.9696
# Epoch [33/120], Step [75/164],                         Loss: 0.0113, mIoU: 0.9685
# Epoch [33/120], Step [100/164],                         Loss: 0.0165, mIoU: 0.9693
# Epoch [33/120], Step [125/164],                         Loss: 0.0145, mIoU: 0.9698
# Epoch [33/120], Step [150/164],                         Loss: 0.0212, mIoU: 0.9693
# Start validation #33
# Validation #33  Average Loss: 0.4572, Accuracy : 0.9195,                 mIoU: 0.5166
# IoU by class : [{'Backgroud': 0.9511}, {'General trash': 0.3539}, {'Paper': 0.7139}, {'Paper pack': 0.3151}, {'Metal': 0.3218}, {'Glass': 0.4806}, {'Plastic': 0.3662}, {'Styrofoam': 0.6463}, {'Plastic bag': 0.8179}, {'Battery': 0.4177}, {'Clothing': 0.2977}]
# Epoch [34/120], Step [25/164],                         Loss: 0.0165, mIoU: 0.9672
# Epoch [34/120], Step [50/164],                         Loss: 0.0149, mIoU: 0.9696
# Epoch [34/120], Step [75/164],                         Loss: 0.0293, mIoU: 0.9698
# Epoch [34/120], Step [100/164],                         Loss: 0.026, mIoU: 0.97
# Epoch [34/120], Step [125/164],                         Loss: 0.0239, mIoU: 0.9694
# Epoch [34/120], Step [150/164],                         Loss: 0.0169, mIoU: 0.9694
# Start validation #34
# Validation #34  Average Loss: 0.4738, Accuracy : 0.9184,                 mIoU: 0.5016
# IoU by class : [{'Backgroud': 0.9512}, {'General trash': 0.349}, {'Paper': 0.7222}, {'Paper pack': 0.3169}, {'Metal': 0.3002}, {'Glass': 0.4468}, {'Plastic': 0.3659}, {'Styrofoam': 0.6402}, {'Plastic bag': 0.82}, {'Battery': 0.3098}, {'Clothing': 0.295}]
# Epoch [35/120], Step [25/164],                         Loss: 0.0211, mIoU: 0.8857
# Epoch [35/120], Step [50/164],                         Loss: 0.0183, mIoU: 0.9726
# Epoch [35/120], Step [75/164],                         Loss: 0.0163, mIoU: 0.9715
# Epoch [35/120], Step [100/164],                         Loss: 0.0174, mIoU: 0.971
# Epoch [35/120], Step [125/164],                         Loss: 0.0184, mIoU: 0.9706
# Epoch [35/120], Step [150/164],                         Loss: 0.0192, mIoU: 0.9711
# Start validation #35
# Validation #35  Average Loss: 0.4757, Accuracy : 0.9186,                 mIoU: 0.5153
# IoU by class : [{'Backgroud': 0.9517}, {'General trash': 0.3618}, {'Paper': 0.7128}, {'Paper pack': 0.3024}, {'Metal': 0.3042}, {'Glass': 0.471}, {'Plastic': 0.3696}, {'Styrofoam': 0.6407}, {'Plastic bag': 0.8186}, {'Battery': 0.452}, {'Clothing': 0.2832}]
# Epoch [36/120], Step [25/164],                         Loss: 0.014, mIoU: 0.9715
# Epoch [36/120], Step [50/164],                         Loss: 0.0112, mIoU: 0.9721
# Epoch [36/120], Step [75/164],                         Loss: 0.0176, mIoU: 0.9715
# Epoch [36/120], Step [100/164],                         Loss: 0.013, mIoU: 0.9719
# Epoch [36/120], Step [125/164],                         Loss: 0.0198, mIoU: 0.9723
# Epoch [36/120], Step [150/164],                         Loss: 0.0258, mIoU: 0.9727
# Start validation #36
# Validation #36  Average Loss: 0.4782, Accuracy : 0.9194,                 mIoU: 0.5166
# IoU by class : [{'Backgroud': 0.9521}, {'General trash': 0.3534}, {'Paper': 0.7184}, {'Paper pack': 0.327}, {'Metal': 0.3192}, {'Glass': 0.4547}, {'Plastic': 0.3784}, {'Styrofoam': 0.6428}, {'Plastic bag': 0.8219}, {'Battery': 0.43}, {'Clothing': 0.2845}]
# Epoch [37/120], Step [25/164],                         Loss: 0.0168, mIoU: 0.9205
# Epoch [37/120], Step [50/164],                         Loss: 0.0199, mIoU: 0.9715
# Epoch [37/120], Step [75/164],                         Loss: 0.0493, mIoU: 0.9645
# Epoch [37/120], Step [100/164],                         Loss: 0.2437, mIoU: 0.8813
# Epoch [37/120], Step [125/164],                         Loss: 0.4541, mIoU: 0.7801
# Epoch [37/120], Step [150/164],                         Loss: 0.1518, mIoU: 0.7274
# Start validation #37
# Validation #37  Average Loss: 0.5136, Accuracy : 0.8626,                 mIoU: 0.3159
# IoU by class : [{'Backgroud': 0.9267}, {'General trash': 0.2383}, {'Paper': 0.5945}, {'Paper pack': 0.2806}, {'Metal': 0.237}, {'Glass': 0.2053}, {'Plastic': 0.2029}, {'Styrofoam': 0.1282}, {'Plastic bag': 0.6238}, {'Battery': 0.007}, {'Clothing': 0.0304}]
# Epoch [38/120], Step [25/164],                         Loss: 0.1835, mIoU: 0.5392
# Epoch [38/120], Step [50/164],                         Loss: 0.1007, mIoU: 0.624
# Epoch [38/120], Step [75/164],                         Loss: 0.124, mIoU: 0.6532
# Epoch [38/120], Step [100/164],                         Loss: 0.1372, mIoU: 0.6628
# Epoch [38/120], Step [125/164],                         Loss: 0.1502, mIoU: 0.678
# Epoch [38/120], Step [150/164],                         Loss: 0.1911, mIoU: 0.6888
# Start validation #38
# Validation #38  Average Loss: 0.3755, Accuracy : 0.9002,                 mIoU: 0.4333
# IoU by class : [{'Backgroud': 0.9396}, {'General trash': 0.2941}, {'Paper': 0.6195}, {'Paper pack': 0.1991}, {'Metal': 0.2068}, {'Glass': 0.4788}, {'Plastic': 0.3434}, {'Styrofoam': 0.4522}, {'Plastic bag': 0.7848}, {'Battery': 0.2093}, {'Clothing': 0.2384}]
# Epoch [39/120], Step [25/164],                         Loss: 0.0626, mIoU: 0.7792
# Epoch [39/120], Step [50/164],                         Loss: 0.0675, mIoU: 0.7704
# Epoch [39/120], Step [75/164],                         Loss: 0.0499, mIoU: 0.8066
# Epoch [39/120], Step [100/164],                         Loss: 0.0477, mIoU: 0.8459
# Epoch [39/120], Step [125/164],                         Loss: 0.035, mIoU: 0.8555
# Epoch [39/120], Step [150/164],                         Loss: 0.0578, mIoU: 0.8665
# Start validation #39
# Validation #39  Average Loss: 0.3612, Accuracy : 0.9125,                 mIoU: 0.4876
# IoU by class : [{'Backgroud': 0.9479}, {'General trash': 0.316}, {'Paper': 0.6922}, {'Paper pack': 0.3154}, {'Metal': 0.2779}, {'Glass': 0.4081}, {'Plastic': 0.3592}, {'Styrofoam': 0.6467}, {'Plastic bag': 0.8094}, {'Battery': 0.3263}, {'Clothing': 0.2646}]
# Epoch [40/120], Step [25/164],                         Loss: 0.0294, mIoU: 0.9286
# Epoch [40/120], Step [50/164],                         Loss: 0.0275, mIoU: 0.9362
# Epoch [40/120], Step [75/164],                         Loss: 0.0403, mIoU: 0.9372
# Epoch [40/120], Step [100/164],                         Loss: 0.0317, mIoU: 0.9369
# Epoch [40/120], Step [125/164],                         Loss: 0.0304, mIoU: 0.938
# Epoch [40/120], Step [150/164],                         Loss: 0.03, mIoU: 0.9402
# Start validation #40
# Validation #40  Average Loss: 0.3763, Accuracy : 0.9183,                 mIoU: 0.5133
# IoU by class : [{'Backgroud': 0.9513}, {'General trash': 0.3664}, {'Paper': 0.7138}, {'Paper pack': 0.3252}, {'Metal': 0.3297}, {'Glass': 0.4503}, {'Plastic': 0.3582}, {'Styrofoam': 0.6566}, {'Plastic bag': 0.8134}, {'Battery': 0.4249}, {'Clothing': 0.2561}]
# Epoch [41/120], Step [25/164],                         Loss: 0.0285, mIoU: 0.9537
# Epoch [41/120], Step [50/164],                         Loss: 0.0285, mIoU: 0.956
# Epoch [41/120], Step [75/164],                         Loss: 0.0259, mIoU: 0.9566
# Epoch [41/120], Step [100/164],                         Loss: 0.0256, mIoU: 0.9577
# Epoch [41/120], Step [125/164],                         Loss: 0.0203, mIoU: 0.9577
# Epoch [41/120], Step [150/164],                         Loss: 0.0263, mIoU: 0.9584
# Start validation #41
# Validation #41  Average Loss: 0.4015, Accuracy : 0.9197,                 mIoU: 0.5092
# IoU by class : [{'Backgroud': 0.9518}, {'General trash': 0.3694}, {'Paper': 0.7137}, {'Paper pack': 0.312}, {'Metal': 0.3358}, {'Glass': 0.4507}, {'Plastic': 0.3648}, {'Styrofoam': 0.6747}, {'Plastic bag': 0.8173}, {'Battery': 0.3343}, {'Clothing': 0.2764}]
# Epoch [42/120], Step [25/164],                         Loss: 0.0183, mIoU: 0.9161
# Epoch [42/120], Step [50/164],                         Loss: 0.021, mIoU: 0.9624
# Epoch [42/120], Step [75/164],                         Loss: 0.0311, mIoU: 0.9626
# Epoch [42/120], Step [100/164],                         Loss: 0.019, mIoU: 0.9639
# Epoch [42/120], Step [125/164],                         Loss: 0.0341, mIoU: 0.9652
# Epoch [42/120], Step [150/164],                         Loss: 0.016, mIoU: 0.9654
# Start validation #42
# Validation #42  Average Loss: 0.4084, Accuracy : 0.9202,                 mIoU: 0.5145
# IoU by class : [{'Backgroud': 0.9523}, {'General trash': 0.3697}, {'Paper': 0.7158}, {'Paper pack': 0.3638}, {'Metal': 0.3414}, {'Glass': 0.4454}, {'Plastic': 0.3829}, {'Styrofoam': 0.6779}, {'Plastic bag': 0.8183}, {'Battery': 0.3257}, {'Clothing': 0.2663}]
# Epoch [43/120], Step [25/164],                         Loss: 0.0224, mIoU: 0.9679
# Epoch [43/120], Step [50/164],                         Loss: 0.0195, mIoU: 0.9671
# Epoch [43/120], Step [75/164],                         Loss: 0.0156, mIoU: 0.9668
# Epoch [43/120], Step [100/164],                         Loss: 0.0249, mIoU: 0.9682
# Epoch [43/120], Step [125/164],                         Loss: 0.0291, mIoU: 0.9684
# Epoch [43/120], Step [150/164],                         Loss: 0.0221, mIoU: 0.9688
# Start validation #43
# Validation #43  Average Loss: 0.434, Accuracy : 0.9201,                 mIoU: 0.5182
# IoU by class : [{'Backgroud': 0.9522}, {'General trash': 0.3736}, {'Paper': 0.7196}, {'Paper pack': 0.3608}, {'Metal': 0.3142}, {'Glass': 0.4553}, {'Plastic': 0.3816}, {'Styrofoam': 0.6793}, {'Plastic bag': 0.8183}, {'Battery': 0.374}, {'Clothing': 0.2713}]
# Epoch [44/120], Step [25/164],                         Loss: 0.0204, mIoU: 0.9686
# Epoch [44/120], Step [50/164],                         Loss: 0.0202, mIoU: 0.9695
# Epoch [44/120], Step [75/164],                         Loss: 0.0131, mIoU: 0.9711
# Epoch [44/120], Step [100/164],                         Loss: 0.0152, mIoU: 0.9715
# Epoch [44/120], Step [125/164],                         Loss: 0.0191, mIoU: 0.971
# Epoch [44/120], Step [150/164],                         Loss: 0.0165, mIoU: 0.971
# Start validation #44
# Validation #44  Average Loss: 0.4301, Accuracy : 0.9214,                 mIoU: 0.5152
# IoU by class : [{'Backgroud': 0.9533}, {'General trash': 0.3761}, {'Paper': 0.7169}, {'Paper pack': 0.3558}, {'Metal': 0.3252}, {'Glass': 0.4599}, {'Plastic': 0.3788}, {'Styrofoam': 0.6814}, {'Plastic bag': 0.8226}, {'Battery': 0.3288}, {'Clothing': 0.2688}]
# Epoch [45/120], Step [25/164],                         Loss: 0.0136, mIoU: 0.9694
# Epoch [45/120], Step [50/164],                         Loss: 0.0099, mIoU: 0.9715
# Epoch [45/120], Step [75/164],                         Loss: 0.02, mIoU: 0.9717
# Epoch [45/120], Step [100/164],                         Loss: 0.0179, mIoU: 0.9718
# Epoch [45/120], Step [125/164],                         Loss: 0.0159, mIoU: 0.9725
# Epoch [45/120], Step [150/164],                         Loss: 0.017, mIoU: 0.9723
# Start validation #45
# Validation #45  Average Loss: 0.4364, Accuracy : 0.9212,                 mIoU: 0.5213
# IoU by class : [{'Backgroud': 0.9534}, {'General trash': 0.381}, {'Paper': 0.7233}, {'Paper pack': 0.3651}, {'Metal': 0.347}, {'Glass': 0.4607}, {'Plastic': 0.3766}, {'Styrofoam': 0.6794}, {'Plastic bag': 0.8227}, {'Battery': 0.3551}, {'Clothing': 0.2702}]
# Epoch [46/120], Step [25/164],                         Loss: 0.0165, mIoU: 0.9718
# Epoch [46/120], Step [50/164],                         Loss: 0.0126, mIoU: 0.9712
# Epoch [46/120], Step [75/164],                         Loss: 0.0253, mIoU: 0.9728
# Epoch [46/120], Step [100/164],                         Loss: 0.0219, mIoU: 0.9737
# Epoch [46/120], Step [125/164],                         Loss: 0.0151, mIoU: 0.9735
# Epoch [46/120], Step [150/164],                         Loss: 0.0176, mIoU: 0.9737
# Start validation #46
# Validation #46  Average Loss: 0.4511, Accuracy : 0.9214,                 mIoU: 0.5195
# IoU by class : [{'Backgroud': 0.9535}, {'General trash': 0.3751}, {'Paper': 0.7215}, {'Paper pack': 0.358}, {'Metal': 0.3132}, {'Glass': 0.4527}, {'Plastic': 0.3808}, {'Styrofoam': 0.6793}, {'Plastic bag': 0.8215}, {'Battery': 0.379}, {'Clothing': 0.2799}]
# Epoch [47/120], Step [25/164],                         Loss: 0.0137, mIoU: 0.9742
# Epoch [47/120], Step [50/164],                         Loss: 0.0239, mIoU: 0.974
# Epoch [47/120], Step [75/164],                         Loss: 0.0154, mIoU: 0.9743
# Epoch [47/120], Step [100/164],                         Loss: 0.0157, mIoU: 0.9735
# Epoch [47/120], Step [125/164],                         Loss: 0.0159, mIoU: 0.9738
# Epoch [47/120], Step [150/164],                         Loss: 0.012, mIoU: 0.974
# Start validation #47
# Validation #47  Average Loss: 0.4679, Accuracy : 0.9215,                 mIoU: 0.521
# IoU by class : [{'Backgroud': 0.9532}, {'General trash': 0.3685}, {'Paper': 0.7201}, {'Paper pack': 0.3436}, {'Metal': 0.3319}, {'Glass': 0.461}, {'Plastic': 0.3897}, {'Styrofoam': 0.6733}, {'Plastic bag': 0.8226}, {'Battery': 0.3898}, {'Clothing': 0.2775}]
# Epoch [48/120], Step [25/164],                         Loss: 0.0231, mIoU: 0.9764
# Epoch [48/120], Step [50/164],                         Loss: 0.0163, mIoU: 0.9761
# Epoch [48/120], Step [75/164],                         Loss: 0.016, mIoU: 0.9752
# Epoch [48/120], Step [100/164],                         Loss: 0.0206, mIoU: 0.9746
# Epoch [48/120], Step [125/164],                         Loss: 0.016, mIoU: 0.9745
# Epoch [48/120], Step [150/164],                         Loss: 0.016, mIoU: 0.9752
# Start validation #48
# Validation #48  Average Loss: 0.4619, Accuracy : 0.9214,                 mIoU: 0.5211
# IoU by class : [{'Backgroud': 0.9535}, {'General trash': 0.3765}, {'Paper': 0.7233}, {'Paper pack': 0.3498}, {'Metal': 0.3171}, {'Glass': 0.4546}, {'Plastic': 0.3863}, {'Styrofoam': 0.6772}, {'Plastic bag': 0.8219}, {'Battery': 0.4005}, {'Clothing': 0.2716}]
# Epoch [49/120], Step [25/164],                         Loss: 0.0225, mIoU: 0.9732
# Epoch [49/120], Step [50/164],                         Loss: 0.0231, mIoU: 0.9749
# Epoch [49/120], Step [75/164],                         Loss: 0.0142, mIoU: 0.9754
# Epoch [49/120], Step [100/164],                         Loss: 0.0114, mIoU: 0.9749
# Epoch [49/120], Step [125/164],                         Loss: 0.015, mIoU: 0.9754
# Epoch [49/120], Step [150/164],                         Loss: 0.0092, mIoU: 0.9758
# Start validation #49
# Validation #49  Average Loss: 0.4605, Accuracy : 0.9216,                 mIoU: 0.5186
# IoU by class : [{'Backgroud': 0.9533}, {'General trash': 0.3734}, {'Paper': 0.7234}, {'Paper pack': 0.3642}, {'Metal': 0.3292}, {'Glass': 0.457}, {'Plastic': 0.3778}, {'Styrofoam': 0.6721}, {'Plastic bag': 0.8194}, {'Battery': 0.3721}, {'Clothing': 0.2629}]
# Epoch [50/120], Step [25/164],                         Loss: 0.0097, mIoU: 0.9778
# Epoch [50/120], Step [50/164],                         Loss: 0.0124, mIoU: 0.9768
# Epoch [50/120], Step [75/164],                         Loss: 0.0144, mIoU: 0.9766
# Epoch [50/120], Step [100/164],                         Loss: 0.0141, mIoU: 0.9767
# Epoch [50/120], Step [125/164],                         Loss: 0.0156, mIoU: 0.9761
# Epoch [50/120], Step [150/164],                         Loss: 0.0177, mIoU: 0.9767
# Start validation #50
# Validation #50  Average Loss: 0.4787, Accuracy : 0.9214,                 mIoU: 0.5111
# IoU by class : [{'Backgroud': 0.954}, {'General trash': 0.3774}, {'Paper': 0.721}, {'Paper pack': 0.3591}, {'Metal': 0.3007}, {'Glass': 0.4425}, {'Plastic': 0.3853}, {'Styrofoam': 0.677}, {'Plastic bag': 0.8217}, {'Battery': 0.3164}, {'Clothing': 0.2671}]
# Epoch [51/120], Step [25/164],                         Loss: 0.0135, mIoU: 0.9763
# Epoch [51/120], Step [50/164],                         Loss: 0.0184, mIoU: 0.9766
# Epoch [51/120], Step [75/164],                         Loss: 0.0122, mIoU: 0.9765
# Epoch [51/120], Step [100/164],                         Loss: 0.0127, mIoU: 0.9766
# Epoch [51/120], Step [125/164],                         Loss: 0.0168, mIoU: 0.9764
# Epoch [51/120], Step [150/164],                         Loss: 0.018, mIoU: 0.9764
# Start validation #51
# Validation #51  Average Loss: 0.4832, Accuracy : 0.9208,                 mIoU: 0.5118
# IoU by class : [{'Backgroud': 0.9536}, {'General trash': 0.3721}, {'Paper': 0.7222}, {'Paper pack': 0.3439}, {'Metal': 0.2985}, {'Glass': 0.4595}, {'Plastic': 0.379}, {'Styrofoam': 0.6766}, {'Plastic bag': 0.8239}, {'Battery': 0.3216}, {'Clothing': 0.2791}]
# Epoch [52/120], Step [25/164],                         Loss: 0.0162, mIoU: 0.979
# Epoch [52/120], Step [50/164],                         Loss: 0.0148, mIoU: 0.9782
# Epoch [52/120], Step [75/164],                         Loss: 0.0152, mIoU: 0.9763
# Epoch [52/120], Step [100/164],                         Loss: 0.0151, mIoU: 0.9765
# Epoch [52/120], Step [125/164],                         Loss: 0.0147, mIoU: 0.977
# Epoch [52/120], Step [150/164],                         Loss: 0.02, mIoU: 0.9767
# Start validation #52
# Validation #52  Average Loss: 0.4912, Accuracy : 0.9206,                 mIoU: 0.5152
# IoU by class : [{'Backgroud': 0.9533}, {'General trash': 0.3672}, {'Paper': 0.7177}, {'Paper pack': 0.3384}, {'Metal': 0.2991}, {'Glass': 0.4626}, {'Plastic': 0.3812}, {'Styrofoam': 0.6693}, {'Plastic bag': 0.82}, {'Battery': 0.3719}, {'Clothing': 0.2865}]
# Epoch [53/120], Step [25/164],                         Loss: 0.0228, mIoU: 0.9775
# Epoch [53/120], Step [50/164],                         Loss: 0.0145, mIoU: 0.9776
# Epoch [53/120], Step [75/164],                         Loss: 0.0113, mIoU: 0.9776
# Epoch [53/120], Step [100/164],                         Loss: 0.0757, mIoU: 0.9711
# Epoch [53/120], Step [125/164],                         Loss: 0.321, mIoU: 0.9445
# Epoch [53/120], Step [150/164],                         Loss: 0.2267, mIoU: 0.8782
# Start validation #53
# Validation #53  Average Loss: 0.5499, Accuracy : 0.8559,                 mIoU: 0.32
# IoU by class : [{'Backgroud': 0.9197}, {'General trash': 0.1301}, {'Paper': 0.5496}, {'Paper pack': 0.1278}, {'Metal': 0.2259}, {'Glass': 0.2521}, {'Plastic': 0.2381}, {'Styrofoam': 0.3703}, {'Plastic bag': 0.5641}, {'Battery': 0.0072}, {'Clothing': 0.1353}]
# Epoch [54/120], Step [25/164],                         Loss: 0.1504, mIoU: 0.6087
# Epoch [54/120], Step [50/164],                         Loss: 0.1061, mIoU: 0.6223
# Epoch [54/120], Step [75/164],                         Loss: 0.169, mIoU: 0.6641
# Epoch [54/120], Step [100/164],                         Loss: 0.0743, mIoU: 0.6775
# Epoch [54/120], Step [125/164],                         Loss: 0.1202, mIoU: 0.6951
# Epoch [54/120], Step [150/164],                         Loss: 0.0907, mIoU: 0.7166
# Start validation #54
# Validation #54  Average Loss: 0.3722, Accuracy : 0.9082,                 mIoU: 0.48
# IoU by class : [{'Backgroud': 0.9416}, {'General trash': 0.3655}, {'Paper': 0.6878}, {'Paper pack': 0.3449}, {'Metal': 0.2704}, {'Glass': 0.3473}, {'Plastic': 0.2489}, {'Styrofoam': 0.5828}, {'Plastic bag': 0.7906}, {'Battery': 0.4159}, {'Clothing': 0.2844}]
# Epoch [55/120], Step [25/164],                         Loss: 0.07, mIoU: 0.9029
# Epoch [55/120], Step [50/164],                         Loss: 0.0925, mIoU: 0.91
# Epoch [55/120], Step [75/164],                         Loss: 0.043, mIoU: 0.9136
# Epoch [55/120], Step [100/164],                         Loss: 0.0344, mIoU: 0.9154
# Epoch [55/120], Step [125/164],                         Loss: 0.0327, mIoU: 0.9172
# Epoch [55/120], Step [150/164],                         Loss: 0.0298, mIoU: 0.9221
# Start validation #55
# Validation #55  Average Loss: 0.3903, Accuracy : 0.9116,                 mIoU: 0.5116
# IoU by class : [{'Backgroud': 0.9461}, {'General trash': 0.3412}, {'Paper': 0.6955}, {'Paper pack': 0.3338}, {'Metal': 0.3411}, {'Glass': 0.4342}, {'Plastic': 0.3594}, {'Styrofoam': 0.6356}, {'Plastic bag': 0.7961}, {'Battery': 0.4439}, {'Clothing': 0.301}]
# Epoch [56/120], Step [25/164],                         Loss: 0.0333, mIoU: 0.962
# Epoch [56/120], Step [50/164],                         Loss: 0.0402, mIoU: 0.9595
# Epoch [56/120], Step [75/164],                         Loss: 0.0194, mIoU: 0.9587
# Epoch [56/120], Step [100/164],                         Loss: 0.0158, mIoU: 0.9569
# Epoch [56/120], Step [125/164],                         Loss: 0.0268, mIoU: 0.9576
# Epoch [56/120], Step [150/164],                         Loss: 0.0249, mIoU: 0.9576
# Start validation #56
# Validation #56  Average Loss: 0.4198, Accuracy : 0.9175,                 mIoU: 0.5207
# ...
# Start validation #102
# Validation #102  Average Loss: 0.5373, Accuracy : 0.9188,                 mIoU: 0.5123
# IoU by class : [{'Backgroud': 0.9509}, {'General trash': 0.3813}, {'Paper': 0.7113}, {'Paper pack': 0.364}, {'Metal': 0.3181}, {'Glass': 0.4464}, {'Plastic': 0.3676}, {'Styrofoam': 0.6535}, {'Plastic bag': 0.8133}, {'Battery': 0.3562}, {'Clothing': 0.2726}]
# Epoch [103/120], Step [25/164],                         Loss: 0.019, mIoU: 0.9822
# Epoch [103/120], Step [50/164],                         Loss: 0.0116, mIoU: 0.9824
# Epoch [103/120], Step [75/164],                         Loss: 0.0125, mIoU: 0.9825
# Epoch [103/120], Step [100/164],                         Loss: 0.0123, mIoU: 0.9826
# Epoch [103/120], Step [125/164],                         Loss: 0.0118, mIoU: 0.9826
# Epoch [103/120], Step [150/164],                         Loss: 0.0095, mIoU: 0.9827
# Start validation #103
# Validation #103  Average Loss: 0.5422, Accuracy : 0.9193,                 mIoU: 0.5181
# IoU by class : [{'Backgroud': 0.9512}, {'General trash': 0.3805}, {'Paper': 0.7127}, {'Paper pack': 0.3694}, {'Metal': 0.3295}, {'Glass': 0.4564}, {'Plastic': 0.3683}, {'Styrofoam': 0.6522}, {'Plastic bag': 0.8153}, {'Battery': 0.3833}, {'Clothing': 0.2804}]
# Epoch [104/120], Step [25/164],                         Loss: 0.0139, mIoU: 0.985
# Epoch [104/120], Step [50/164],                         Loss: 0.013, mIoU: 0.9837
# Epoch [104/120], Step [75/164],                         Loss: 0.0143, mIoU: 0.9833
# Epoch [104/120], Step [100/164],                         Loss: 0.0064, mIoU: 0.9829
# Epoch [104/120], Step [125/164],                         Loss: 0.0101, mIoU: 0.9829
# Epoch [104/120], Step [150/164],                         Loss: 0.0116, mIoU: 0.9831
# Start validation #104
# Validation #104  Average Loss: 0.5611, Accuracy : 0.9192,                 mIoU: 0.5134
# IoU by class : [{'Backgroud': 0.9512}, {'General trash': 0.3754}, {'Paper': 0.7138}, {'Paper pack': 0.3646}, {'Metal': 0.332}, {'Glass': 0.4575}, {'Plastic': 0.3624}, {'Styrofoam': 0.6553}, {'Plastic bag': 0.8155}, {'Battery': 0.3407}, {'Clothing': 0.2788}]
# Epoch [105/120], Step [25/164],                         Loss: 0.007, mIoU: 0.9842
# Epoch [105/120], Step [50/164],                         Loss: 0.0121, mIoU: 0.9833
# Epoch [105/120], Step [75/164],                         Loss: 0.0085, mIoU: 0.9836
# Epoch [105/120], Step [100/164],                         Loss: 0.0115, mIoU: 0.9839
# Epoch [105/120], Step [125/164],                         Loss: 0.0112, mIoU: 0.9834
# Epoch [105/120], Step [150/164],                         Loss: 0.0105, mIoU: 0.9834
# Start validation #105
# Validation #105  Average Loss: 0.5535, Accuracy : 0.9192,                 mIoU: 0.5213
# IoU by class : [{'Backgroud': 0.951}, {'General trash': 0.3796}, {'Paper': 0.7151}, {'Paper pack': 0.3744}, {'Metal': 0.3308}, {'Glass': 0.458}, {'Plastic': 0.3678}, {'Styrofoam': 0.6551}, {'Plastic bag': 0.8157}, {'Battery': 0.4164}, {'Clothing': 0.2709}]
# Epoch [106/120], Step [25/164],                         Loss: 0.0112, mIoU: 0.9851
# Epoch [106/120], Step [50/164],                         Loss: 0.0084, mIoU: 0.9845
# Epoch [106/120], Step [75/164],                         Loss: 0.0077, mIoU: 0.9846
# Epoch [106/120], Step [100/164],                         Loss: 0.0102, mIoU: 0.9842
# Epoch [106/120], Step [125/164],                         Loss: 0.0144, mIoU: 0.984
# Epoch [106/120], Step [150/164],                         Loss: 0.0129, mIoU: 0.9839
# Start validation #106
# Validation #106  Average Loss: 0.577, Accuracy : 0.9192,                 mIoU: 0.5137
# IoU by class : [{'Backgroud': 0.9509}, {'General trash': 0.376}, {'Paper': 0.7143}, {'Paper pack': 0.3688}, {'Metal': 0.3231}, {'Glass': 0.439}, {'Plastic': 0.3693}, {'Styrofoam': 0.6551}, {'Plastic bag': 0.8155}, {'Battery': 0.3635}, {'Clothing': 0.2751}]
# Epoch [107/120], Step [25/164],                         Loss: 0.0134, mIoU: 0.9839
# Epoch [107/120], Step [50/164],                         Loss: 0.0102, mIoU: 0.9836
# Epoch [107/120], Step [75/164],                         Loss: 0.0102, mIoU: 0.9837
# Epoch [107/120], Step [100/164],                         Loss: 0.0082, mIoU: 0.9838
# Epoch [107/120], Step [125/164],                         Loss: 0.0086, mIoU: 0.9837
# Epoch [107/120], Step [150/164],                         Loss: 0.0128, mIoU: 0.9836
# Start validation #107
# Validation #107  Average Loss: 0.5701, Accuracy : 0.9196,                 mIoU: 0.5146
# IoU by class : [{'Backgroud': 0.9515}, {'General trash': 0.382}, {'Paper': 0.7163}, {'Paper pack': 0.3786}, {'Metal': 0.3149}, {'Glass': 0.4597}, {'Plastic': 0.3677}, {'Styrofoam': 0.658}, {'Plastic bag': 0.8177}, {'Battery': 0.3356}, {'Clothing': 0.2789}]
# Epoch [108/120], Step [25/164],                         Loss: 0.0072, mIoU: 0.9831
# Epoch [108/120], Step [50/164],                         Loss: 0.0085, mIoU: 0.9838
# Epoch [108/120], Step [75/164],                         Loss: 0.0078, mIoU: 0.9832
# Epoch [108/120], Step [100/164],                         Loss: 0.0088, mIoU: 0.9832
# Epoch [108/120], Step [125/164],                         Loss: 0.0105, mIoU: 0.9834
# Epoch [108/120], Step [150/164],                         Loss: 0.0084, mIoU: 0.9837
# Start validation #108
# Validation #108  Average Loss: 0.5763, Accuracy : 0.9196,                 mIoU: 0.5143
# IoU by class : [{'Backgroud': 0.9511}, {'General trash': 0.3789}, {'Paper': 0.7143}, {'Paper pack': 0.3551}, {'Metal': 0.3288}, {'Glass': 0.4623}, {'Plastic': 0.3694}, {'Styrofoam': 0.6546}, {'Plastic bag': 0.8156}, {'Battery': 0.3508}, {'Clothing': 0.277}]
# Epoch [109/120], Step [25/164],                         Loss: 0.0131, mIoU: 0.9825
# Epoch [109/120], Step [50/164],                         Loss: 0.0133, mIoU: 0.9832
# Epoch [109/120], Step [75/164],                         Loss: 0.0103, mIoU: 0.9842
# Epoch [109/120], Step [100/164],                         Loss: 0.0135, mIoU: 0.9839
# Epoch [109/120], Step [125/164],                         Loss: 0.0113, mIoU: 0.9842
# Epoch [109/120], Step [150/164],                         Loss: 0.01, mIoU: 0.9841
# Start validation #109
# Validation #109  Average Loss: 0.5842, Accuracy : 0.9195,                 mIoU: 0.5124
# IoU by class : [{'Backgroud': 0.9512}, {'General trash': 0.3825}, {'Paper': 0.714}, {'Paper pack': 0.358}, {'Metal': 0.3255}, {'Glass': 0.428}, {'Plastic': 0.3748}, {'Styrofoam': 0.6576}, {'Plastic bag': 0.8178}, {'Battery': 0.3624}, {'Clothing': 0.265}]
# Epoch [110/120], Step [25/164],                         Loss: 0.0094, mIoU: 0.9848
# Epoch [110/120], Step [50/164],                         Loss: 0.0102, mIoU: 0.9853
# Epoch [110/120], Step [75/164],                         Loss: 0.0155, mIoU: 0.9845
# Epoch [110/120], Step [100/164],                         Loss: 0.012, mIoU: 0.9841
# Epoch [110/120], Step [125/164],                         Loss: 0.0117, mIoU: 0.9841
# Epoch [110/120], Step [150/164],                         Loss: 0.0086, mIoU: 0.984
# Start validation #110
# Validation #110  Average Loss: 0.5922, Accuracy : 0.9194,                 mIoU: 0.5213
# IoU by class : [{'Backgroud': 0.9515}, {'General trash': 0.375}, {'Paper': 0.7133}, {'Paper pack': 0.3569}, {'Metal': 0.3382}, {'Glass': 0.4653}, {'Plastic': 0.3686}, {'Styrofoam': 0.6612}, {'Plastic bag': 0.8166}, {'Battery': 0.3931}, {'Clothing': 0.2947}]
# Epoch [111/120], Step [25/164],                         Loss: 0.0109, mIoU: 0.9847
# Epoch [111/120], Step [50/164],                         Loss: 0.0083, mIoU: 0.9841
# Epoch [111/120], Step [75/164],                         Loss: 0.0151, mIoU: 0.9847
# Epoch [111/120], Step [100/164],                         Loss: 0.0131, mIoU: 0.9845
# Epoch [111/120], Step [125/164],                         Loss: 0.0154, mIoU: 0.9845
# Epoch [111/120], Step [150/164],                         Loss: 0.0093, mIoU: 0.9845
# Start validation #111
# Validation #111  Average Loss: 0.5846, Accuracy : 0.9196,                 mIoU: 0.5212
# IoU by class : [{'Backgroud': 0.9519}, {'General trash': 0.3769}, {'Paper': 0.7135}, {'Paper pack': 0.3689}, {'Metal': 0.3242}, {'Glass': 0.4691}, {'Plastic': 0.3707}, {'Styrofoam': 0.657}, {'Plastic bag': 0.8168}, {'Battery': 0.398}, {'Clothing': 0.2858}]
# Epoch [112/120], Step [25/164],                         Loss: 0.0126, mIoU: 0.9845
# Epoch [112/120], Step [50/164],                         Loss: 0.0123, mIoU: 0.985
# Epoch [112/120], Step [75/164],                         Loss: 0.0119, mIoU: 0.9848
# Epoch [112/120], Step [100/164],                         Loss: 0.0081, mIoU: 0.9848
# Epoch [112/120], Step [125/164],                         Loss: 0.013, mIoU: 0.9845
# Epoch [112/120], Step [150/164],                         Loss: 0.0109, mIoU: 0.9843
# Start validation #112
# Validation #112  Average Loss: 0.5928, Accuracy : 0.9201,                 mIoU: 0.5188
# IoU by class : [{'Backgroud': 0.9517}, {'General trash': 0.3765}, {'Paper': 0.7147}, {'Paper pack': 0.3667}, {'Metal': 0.3276}, {'Glass': 0.4612}, {'Plastic': 0.3735}, {'Styrofoam': 0.6614}, {'Plastic bag': 0.8185}, {'Battery': 0.3586}, {'Clothing': 0.2961}]
# Epoch [113/120], Step [25/164],                         Loss: 0.0084, mIoU: 0.9841
# Epoch [113/120], Step [50/164],                         Loss: 0.0087, mIoU: 0.9843
# Epoch [113/120], Step [75/164],                         Loss: 0.0079, mIoU: 0.9839
# Epoch [113/120], Step [100/164],                         Loss: 0.0077, mIoU: 0.9844
# Epoch [113/120], Step [125/164],                         Loss: 0.0101, mIoU: 0.9845
# Epoch [113/120], Step [150/164],                         Loss: 0.0119, mIoU: 0.9845
# Start validation #113
# Validation #113  Average Loss: 0.6087, Accuracy : 0.9193,                 mIoU: 0.5136
# IoU by class : [{'Backgroud': 0.9516}, {'General trash': 0.3787}, {'Paper': 0.7168}, {'Paper pack': 0.3671}, {'Metal': 0.3202}, {'Glass': 0.4585}, {'Plastic': 0.3662}, {'Styrofoam': 0.6623}, {'Plastic bag': 0.8151}, {'Battery': 0.3336}, {'Clothing': 0.2795}]
# Epoch [114/120], Step [25/164],                         Loss: 0.0116, mIoU: 0.9836
# Epoch [114/120], Step [50/164],                         Loss: 0.0095, mIoU: 0.9852
# Epoch [114/120], Step [75/164],                         Loss: 0.0112, mIoU: 0.9852
# Epoch [114/120], Step [100/164],                         Loss: 0.0154, mIoU: 0.9849
# Epoch [114/120], Step [125/164],                         Loss: 0.0102, mIoU: 0.9845
# Epoch [114/120], Step [150/164],                         Loss: 0.0095, mIoU: 0.9841
# Start validation #114
# Validation #114  Average Loss: 0.6125, Accuracy : 0.9196,                 mIoU: 0.5032
# IoU by class : [{'Backgroud': 0.9514}, {'General trash': 0.3734}, {'Paper': 0.7135}, {'Paper pack': 0.3432}, {'Metal': 0.3331}, {'Glass': 0.4525}, {'Plastic': 0.3756}, {'Styrofoam': 0.6626}, {'Plastic bag': 0.8189}, {'Battery': 0.2322}, {'Clothing': 0.2794}]
# Epoch [115/120], Step [25/164],                         Loss: 0.0206, mIoU: 0.9808
# Epoch [115/120], Step [50/164],                         Loss: 0.0171, mIoU: 0.9752
# Epoch [115/120], Step [75/164],                         Loss: 0.021, mIoU: 0.9744
# Epoch [115/120], Step [100/164],                         Loss: 0.0366, mIoU: 0.9698
# Epoch [115/120], Step [125/164],                         Loss: 0.1722, mIoU: 0.9352
# Epoch [115/120], Step [150/164],                         Loss: 0.187, mIoU: 0.8668
# Start validation #115
# Validation #115  Average Loss: 0.4412, Accuracy : 0.8757,                 mIoU: 0.3711
# IoU by class : [{'Backgroud': 0.9148}, {'General trash': 0.292}, {'Paper': 0.6375}, {'Paper pack': 0.1316}, {'Metal': 0.2134}, {'Glass': 0.2301}, {'Plastic': 0.2739}, {'Styrofoam': 0.4493}, {'Plastic bag': 0.6838}, {'Battery': 0.102}, {'Clothing': 0.1534}]
# Epoch [116/120], Step [25/164],                         Loss: 0.0564, mIoU: 0.7801
# Epoch [116/120], Step [50/164],                         Loss: 0.0529, mIoU: 0.7985
# Epoch [116/120], Step [75/164],                         Loss: 0.0437, mIoU: 0.8108
# Epoch [116/120], Step [100/164],                         Loss: 0.109, mIoU: 0.8107
# Epoch [116/120], Step [125/164],                         Loss: 0.0335, mIoU: 0.8203
# Epoch [116/120], Step [150/164],                         Loss: 0.0435, mIoU: 0.8229
# Start validation #116
# Validation #116  Average Loss: 0.4073, Accuracy : 0.9048,                 mIoU: 0.4866
# IoU by class : [{'Backgroud': 0.939}, {'General trash': 0.3087}, {'Paper': 0.6687}, {'Paper pack': 0.273}, {'Metal': 0.29}, {'Glass': 0.3944}, {'Plastic': 0.3703}, {'Styrofoam': 0.6187}, {'Plastic bag': 0.7903}, {'Battery': 0.4409}, {'Clothing': 0.2579}]
# Epoch [117/120], Step [25/164],                         Loss: 0.0415, mIoU: 0.9398
# Epoch [117/120], Step [50/164],                         Loss: 0.0232, mIoU: 0.946
# Epoch [117/120], Step [75/164],                         Loss: 0.0245, mIoU: 0.9476
# Epoch [117/120], Step [100/164],                         Loss: 0.0271, mIoU: 0.9503
# Epoch [117/120], Step [125/164],                         Loss: 0.0161, mIoU: 0.9509
# Epoch [117/120], Step [150/164],                         Loss: 0.0245, mIoU: 0.9511
# Start validation #117
# Validation #117  Average Loss: 0.4471, Accuracy : 0.9138,                 mIoU: 0.5077
# IoU by class : [{'Backgroud': 0.9471}, {'General trash': 0.329}, {'Paper': 0.7002}, {'Paper pack': 0.3048}, {'Metal': 0.3192}, {'Glass': 0.4635}, {'Plastic': 0.3704}, {'Styrofoam': 0.5975}, {'Plastic bag': 0.8116}, {'Battery': 0.4787}, {'Clothing': 0.2629}]
# Epoch [118/120], Step [25/164],                         Loss: 0.0276, mIoU: 0.9677
# Epoch [118/120], Step [50/164],                         Loss: 0.0115, mIoU: 0.9709
# Epoch [118/120], Step [75/164],                         Loss: 0.0192, mIoU: 0.971
# Epoch [118/120], Step [100/164],                         Loss: 0.026, mIoU: 0.9719
# Epoch [118/120], Step [125/164],                         Loss: 0.0208, mIoU: 0.9723
# Epoch [118/120], Step [150/164],                         Loss: 0.0175, mIoU: 0.9725
# Start validation #118
# Validation #118  Average Loss: 0.4852, Accuracy : 0.9169,                 mIoU: 0.5194
# IoU by class : [{'Backgroud': 0.9481}, {'General trash': 0.3442}, {'Paper': 0.7111}, {'Paper pack': 0.3522}, {'Metal': 0.3147}, {'Glass': 0.4527}, {'Plastic': 0.378}, {'Styrofoam': 0.6515}, {'Plastic bag': 0.8114}, {'Battery': 0.4912}, {'Clothing': 0.2578}]
# Epoch [119/120], Step [25/164],                         Loss: 0.0147, mIoU: 0.9774
# Epoch [119/120], Step [50/164],                         Loss: 0.0133, mIoU: 0.9774
# Epoch [119/120], Step [75/164],                         Loss: 0.0184, mIoU: 0.9771
# Epoch [119/120], Step [100/164],                         Loss: 0.0096, mIoU: 0.9767
# Epoch [119/120], Step [125/164],                         Loss: 0.0162, mIoU: 0.9773
# Epoch [119/120], Step [150/164],                         Loss: 0.0129, mIoU: 0.9778
# Start validation #119
# Validation #119  Average Loss: 0.5023, Accuracy : 0.9183,                 mIoU: 0.5255
# IoU by class : [{'Backgroud': 0.9488}, {'General trash': 0.365}, {'Paper': 0.7162}, {'Paper pack': 0.3775}, {'Metal': 0.3196}, {'Glass': 0.4464}, {'Plastic': 0.3864}, {'Styrofoam': 0.6472}, {'Plastic bag': 0.8139}, {'Battery': 0.4904}, {'Clothing': 0.2688}]
# Epoch [120/120], Step [25/164],                         Loss: 0.0143, mIoU: 0.9756
# Epoch [120/120], Step [50/164],                         Loss: 0.0162, mIoU: 0.9811
# Epoch [120/120], Step [75/164],                         Loss: 0.0204, mIoU: 0.9802
# Epoch [120/120], Step [100/164],                         Loss: 0.014, mIoU: 0.9799
# Epoch [120/120], Step [125/164],                         Loss: 0.0124, mIoU: 0.9798
# Epoch [120/120], Step [150/164],                         Loss: 0.0128, mIoU: 0.9798
# Start validation #120
# Validation #120  Average Loss: 0.5304, Accuracy : 0.9187,                 mIoU: 0.5238
# IoU by class : [{'Backgroud': 0.9493}, {'General trash': 0.3636}, {'Paper': 0.7162}, {'Paper pack': 0.3593}, {'Metal': 0.3302}, {'Glass': 0.4533}, {'Plastic': 0.3833}, {'Styrofoam': 0.6451}, {'Plastic bag': 0.8163}, {'Battery': 0.4778}, {'Clothing': 0.2679}]

# %% [markdown]
# ## 저장된 model 불러오기 (학습된 이후)

# %%
# best model 저장된 경로
model_path = './saved/fcn_resnet50_best_model(pretrained).pt'

# best model 불러오기
checkpoint = torch.load(model_path, map_location=device)
state_dict = checkpoint.state_dict()
model.load_state_dict(state_dict)

model = model.to(device)
# 추론을 실행하기 전에는 반드시 설정 (batch normalization, dropout 를 평가 모드로 설정)
# model.eval()

# %% [markdown]
# ### `plot_examples()` 시각화 함수 정의

# %%
def plot_examples(mode="train", batch_id=0, num_examples=batch_size, dataloaer=train_loader):
    """Visualization of images and masks according to batch size
    Args:
        mode: train/val/test (str)
        batch_id : 0 (int) 
        num_examples : 1 ~ batch_size(e.g. 8) (int)
        dataloaer : data_loader (dataloader) 
    Returns:
        None
    """
    # variable for legend
    category_and_rgb = [[category, (r,g,b)] for idx, (category, r, g, b) in enumerate(class_colormap.values)]
    legend_elements = [Patch(facecolor=webcolors.rgb_to_hex(rgb), 
                             edgecolor=webcolors.rgb_to_hex(rgb), 
                             label=category) for category, rgb in category_and_rgb]
    
    # test / validation set에 대한 시각화
    if (mode in ('train', 'val')):
        with torch.no_grad():
            for index, (imgs, masks, image_infos) in enumerate(dataloaer):
                if index == batch_id:
                    image_infos = image_infos
                    temp_images = imgs
                    temp_masks = masks

                    model.eval()
                    # inference
                    outs = model(torch.stack(temp_images).to(device))['out']
                    oms = torch.argmax(outs, dim=1).detach().cpu().numpy()

                    break
                else:
                    continue
    
        fig, ax = plt.subplots(nrows=num_examples, ncols=3, figsize=(12, 4*num_examples), constrained_layout=True)
        fig.tight_layout()
        for row_num in range(num_examples):
            # Original Image
            ax[row_num][0].imshow(temp_images[row_num].permute([1,2,0]))
            ax[row_num][0].set_title(f"Orignal Image : {image_infos[row_num]['file_name']}")
            # Groud Truth
            ax[row_num][1].imshow(label_to_color_image(masks[row_num].detach().cpu().numpy()))
            ax[row_num][1].set_title(f"Groud Truth : {image_infos[row_num]['file_name']}")
            # Pred Mask
            ax[row_num][2].imshow(label_to_color_image(oms[row_num]))
            ax[row_num][2].set_title(f"Pred Mask : {image_infos[row_num]['file_name']}")
            ax[row_num][2].legend(handles=legend_elements, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
        plt.show()
    
    # test set에 대한 시각화
    else :
        with torch.no_grad():
            for index, (imgs, image_infos) in enumerate(dataloaer):
                if index == batch_id:
                    image_infos = image_infos
                    temp_images = imgs

                    model.eval()
                    
                    # inference
                    outs = model(torch.stack(temp_images).to(device))['out']
                    oms = torch.argmax(outs, dim=1).detach().cpu().numpy()
                    break
                else:
                    continue
    
        fig, ax = plt.subplots(nrows=num_examples, ncols=2, figsize=(10, 4*num_examples), constrained_layout=True)

        for row_num in range(num_examples):
            # Original Image
            ax[row_num][0].imshow(temp_images[row_num].permute([1,2,0]))
            ax[row_num][0].set_title(f"Orignal Image : {image_infos[row_num]['file_name']}")
            # Pred Mask
            ax[row_num][1].imshow(label_to_color_image(oms[row_num]))
            ax[row_num][1].set_title(f"Pred Mask : {image_infos[row_num]['file_name']}")
            ax[row_num][1].legend(handles=legend_elements, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
            
        plt.show()

# %% [markdown]
# #### train set 시각화

# %%
plot_examples(mode="train", batch_id=7, num_examples=4, dataloaer=train_loader)

# %% [markdown]
# #### validation set 시각화

# %%
plot_examples(mode="val", batch_id=0, num_examples=4, dataloaer=val_loader)

# %% [markdown]
# #### test set 시각화

# %%
plot_examples(mode="test", batch_id=0, num_examples=8, dataloaer=test_loader)

# %% [markdown]
# ## submission을 위한 test 함수 정의

# %%
def test(model, data_loader, device):
    size = 256
    transform = A.Compose([A.Resize(size, size)])
    print('Start prediction.')
    
    model.eval()
    
    file_name_list = []
    preds_array = np.empty((0, size*size), dtype=np.long)
    
    with torch.no_grad():
        for step, (imgs, image_infos) in enumerate(tqdm(test_loader)):
            
            # inference (512 x 512)
            outs = model(torch.stack(imgs).to(device))['out']
            oms = torch.argmax(outs.squeeze(), dim=1).detach().cpu().numpy()
            
            # resize (256 x 256)
            temp_mask = []
            for img, mask in zip(np.stack(imgs), oms):
                transformed = transform(image=img, mask=mask)
                mask = transformed['mask']
                temp_mask.append(mask)
                
            oms = np.array(temp_mask)
            
            oms = oms.reshape([oms.shape[0], size*size]).astype(int)
            preds_array = np.vstack((preds_array, oms))
            
            file_name_list.append([i['file_name'] for i in image_infos])
    print("End prediction.")
    file_names = [y for x in file_name_list for y in x]
    
    return file_names, preds_array

# %% [markdown]
# ## submission.csv 생성

# %%
# sample_submisson.csv 열기
submission = pd.read_csv('./submission/sample_submission.csv', index_col=None)

# test set에 대한 prediction
file_names, preds = test(model, test_loader, device)

# PredictionString 대입
for file_name, string in zip(file_names, preds):
    submission = submission.append({"image_id" : file_name, "PredictionString" : ' '.join(str(e) for e in string.tolist())}, 
                                   ignore_index=True)

# submission.csv로 저장
submission.to_csv("./submission/fcn_resnet50_best_model(pretrained).csv", index=False)
# Out:
#   0%|          | 0/52 [00:00<?, ?it/s]
# Start prediction.
# 100%|██████████| 52/52 [06:38<00:00,  6.00s/it]
# End prediction.
